# %% [markdown]
# <a href="https://colab.research.google.com/github/nattapon44/dpdm/blob/main/Hw_Numpy_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **633020371-2 ณัฐพล สุรศิลป์**

# %% [markdown]
# ให้ทุกคนฝึกฝนด้วยตนเองก่อนคลาสในวันศุกร์
# * อ่านไฟล์ใน Google Drive ของตนเองบน Google Colab
# * อ่านไฟล์ในเครื่องตนเองด้วย Jupyter Notebook ในเครื่องของตน
# * อ่านไฟล์ใน Google Drive ของตนเองผ่าน Jupyter Notebook ในเครื่องของตน ซึ่งสามารถสร้าง sharable link แล้วนำมาเป็น path ของไฟล์ที่ต้องการอ่านได้ (หรือปกติก็สามารถดาวน์โหลดไฟล์ลงเครื่องตนเองแล้วอ่านตามปกติ)

# %% [markdown]
# Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
data_diabetes = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/diabetes.csv')
data_diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
import os
path = '/content/drive/MyDrive/Colab Notebooks/diabetes.csv'
data_covid_cases = pd.read_csv(os.path.join('/content/drive/MyDrive/Colab Notebooks/diabetes.csv'))
data_covid_cases
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# Jupyter

# %%
import pandas as pd
data_diabetes = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRPggP14jHvECEu9gaM-rm94wXhKKyqz3aqOCQ7_sYq22Bp8I4sfbgRGGqrc4YHKA2oeRmOOyRQivJd/pub?output=csv')
data_diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
import numpy as np

# %%
x = np.arange(5)
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
# numpy.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None, axis=0)[source]
y = np.linspace(start = 2, stop = 10, num = 5)
y
# Out:
# array([ 2.,  4.,  6.,  8., 10.])

# %% [markdown]
# Chebyshev distance เป็นการวัดความต่างระหว่างข้อมูลแบบ $L_\infty$ norm ซึ่งเป็นกรณีพิเศษของ Minkowski distance: $\left(\sum_{i=1}^{k} \lvert x_i - y_i \rvert^r\right)^{1/r}$ ที่ $r=\infty$ โดยสามารถคำนวณค่าได้ดังนี้
# $$d(x,y) = \max_{i} \left( \lvert x_{i} - y_{i} \rvert \right)$$

# %% [markdown]
# สร้างฟังก์ชันสำหรับคำนวณ Chebyshev distance ระหว่างเวคเตอร์ 2 เวคเตอร์ ที่แต่ละเวคเตอร์มีขนาด k มิติ (numpy array of length k)

# %%
def Cheby_dist_n(vec1, vec2):
    max = 0
    for i in range(len(vec1)):
        max = np.max(np.abs(vec1[i] - vec2[i]))
    return max

Cheby_dist_n(x, y)
# Out:
# 6.0

# %%
def Cheby_dist_n(vec1, vec2):
    max = 0
    for i in range(len(vec1)):
          distances = np.abs(vec1 - vec2)
          max = np.max(distances)
    return max

Cheby_dist_n(x, y)
# Out:
# 6.0

# %% [markdown]
# Canberra distance เป็นการวัดความต่างระหว่างข้อมูลแบบ Manhattan distance ที่ถ่วงน้ำหนัก (weighted Manhattan distance) โดยคำนวณดังนี้
# $$d(x,y) = \sum_{i=1}^{k} \frac{\lvert x_{i} - y_{i} \rvert}{\lvert x_{i} \rvert + \lvert y_{i} \rvert}$$

# %% [markdown]
# สร้างฟังก์ชันสำหรับคำนวณ Canberra distance ระหว่างเวคเตอร์ 2 เวคเตอร์ ที่แต่ละเวคเตอร์มีขนาด k มิติ

# %%
def canb_dist_n(vec1, vec2):
    for i in range(len(vec1)):
        sum = np.sum(np.abs(vec1 - vec2) / (np.abs(vec1) + np.abs(vec2)))
    return sum

canb_dist_n(x, y)
# Out:
# 2.983116883116883

# %%
def canb_dist_n(vec1, vec2):
    for i in range(len(vec1)):
        dist = np.abs(vec1 - vec2) / (np.abs(vec1) + np.abs(vec2))
        sum = np.sum(dist)
    return sum

canb_dist_n(x, y)
# Out:
# 2.983116883116883

# %% [markdown]
# สร้างฟังก์ชันสำหรับคำนวณค่าเฉลี่ยของค่าในเวคเตอร์หนึ่ง โดยไม่ใช้ฟังก์ชันสำเร็จรูป `mean()` ใช้เพียง numpy array และการบวกลบคูณหาร

# %%
def func_mean(vec):
    mean = np.sum(vec) / len(vec)
    return mean
func_mean(x)
# Out:
# 2.0

# %% [markdown]
# สร้างฟังก์ชันสำหรับคำนวณค่าเบี่ยงเบนมาตรฐานของค่าในเวคเตอร์หนึ่ง โดยไม่ใช้ฟังก์ชัน `std()` หรือ `stddev()` ใช้เพียง numpy array และการบวกลบคูณหาร

# %%
def func_std(vec):
    mean = np.mean(vec)
    diff = vec - mean
    squared_diff = diff ** 2
    variance = np.mean(squared_diff)
    std = np.sqrt(variance)
    return std
func_std(x)
# Out:
# 1.4142135623730951
