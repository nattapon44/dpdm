# %% [markdown]
# <a href="https://colab.research.google.com/github/nattapon44/dpdm/blob/main/newCopy_of_Data_Preprocessing_(Chapter_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # ทำงานกับข้อมูลลักษณะ ตาราง
import numpy as np

# %%
from google.colab import drive # เชื่อม google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os # จัดการไฟล์และ path

# %%
#path = '/content/drive/My Drive/DPDM2021_DATA'
data_cases = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/confirmed-cases.csv')
data_cases
# Out:
# <ipython-input-6-741884d1a33d>:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_cases = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/confirmed-cases.csv')
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [839771 rows x 11 columns]

# %%
data_cases.loc[data_cases['announce_date']=='26/7/2021'].index
# Out:
# Int64Index([497302, 497303, 497304, 497305, 497306, 497307, 497308, 497309,
#             497310, 497311,
#             ...
#             512668, 512669, 512670, 512671, 512672, 512673, 512674, 512675,
#             512676, 512677],
#            dtype='int64', length=15376)

# %% [markdown]
# # ชี้ข้อมูลในตาราง

# %%
data_cases['risk']
# Out:
# 0         คนต่างชาติเดินทางมาจากต่างประเทศ
# 1         คนต่างชาติเดินทางมาจากต่างประเทศ
# 2         คนต่างชาติเดินทางมาจากต่างประเทศ
# 3         คนต่างชาติเดินทางมาจากต่างประเทศ
# 4         คนต่างชาติเดินทางมาจากต่างประเทศ
#                         ...
# 839766                    ทัณฑสถาน/เรือนจำ
# 839767                    ทัณฑสถาน/เรือนจำ
# 839768                    ทัณฑสถาน/เรือนจำ
# 839769                    ทัณฑสถาน/เรือนจำ
# 839770                    ทัณฑสถาน/เรือนจำ
# Name: risk, Length: 839771, dtype: object

# %%
data_cases[['risk','age']]
# Out:
#                                     risk   age
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ  61.0
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ  74.0
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ  73.0
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ  68.0
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ  66.0
# ...                                  ...   ...
# 839766                  ทัณฑสถาน/เรือนจำ  52.0
# 839767                  ทัณฑสถาน/เรือนจำ  34.0
# 839768                  ทัณฑสถาน/เรือนจำ  31.0
# 839769                  ทัณฑสถาน/เรือนจำ  83.0
# 839770                  ทัณฑสถาน/เรือนจำ  47.0
#
# [839771 rows x 2 columns]

# %%
data_cases['risk'][666]
# Out:
# 'สนามมวย'

# %% [markdown]
# # ชี้โดยใช้ .iloc[] (แปลงมุมมองให้เป็น matrix)

# %%
data_cases.iloc[4,4]
# Out:
# 66.0

# %%
data_cases.iloc[-50:,:]
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 839721  839722     12/8/2021     11/8/2021   ชาย  19.0   ปี    Thailand
# 839722  839723     12/8/2021     11/8/2021  หญิง  60.0   ปี    Thailand
# 839723  839724     12/8/2021     11/8/2021  หญิง  49.0   ปี    Thailand
# 839724  839725     12/8/2021     11/8/2021  หญิง  51.0   ปี    Thailand
# 839725  839726     12/8/2021     11/8/2021  หญิง  36.0   ปี    Thailand
# 839726  839727     12/8/2021     11/8/2021  หญิง  44.0   ปี    Thailand
# 839727  839728     12/8/2021     11/8/2021  หญิง  34.0   ปี    Thailand
# 839728  839729     12/8/2021     11/8/2021  หญิง  59.0   ปี    Thailand
# 839729  839730     12/8/2021     11/8/2021  หญิง  53.0   ปี    Thailand
# 839730  839731     12/8/2021     11/8/2021  หญิง  40.0   ปี    Thailand
# 839731  839732     12/8/2021     11/8/2021  หญิง  35.0   ปี    Thailand
# 839732  839733     12/8/2021     11/8/2021  หญิง  26.0   ปี    Thailand
# 839733  839734     12/8/2021     11/8/2021  หญิง  33.0   ปี         NaN
# 839734  839735     12/8/2021     11/8/2021  หญิง  55.0   ปี    Thailand
# 839735  839736     12/8/2021     11/8/2021  หญิง  28.0   ปี    Thailand
# 839736  839737     12/8/2021     11/8/2021  หญิง  40.0   ปี    Thailand
# 839737  839738     12/8/2021     11/8/2021  หญิง  57.0   ปี    Thailand
# 839738  839739     12/8/2021     11/8/2021  หญิง  50.0   ปี         NaN
# 839739  839740     12/8/2021     11/8/2021  หญิง  37.0   ปี    Thailand
# 839740  839741     12/8/2021     11/8/2021  หญิง  24.0   ปี    Thailand
# 839741  839742     12/8/2021     11/8/2021  หญิง  26.0   ปี    Thailand
# 839742  839743     12/8/2021     11/8/2021   ชาย  37.0   ปี         NaN
# 839743  839744     12/8/2021     11/8/2021   ชาย  30.0   ปี    Thailand
# 839744  839745     12/8/2021     11/8/2021   ชาย   NaN  NaN         NaN
# 839745  839746     12/8/2021     11/8/2021   ชาย   NaN  NaN         NaN
# 839746  839747     12/8/2021     11/8/2021   ชาย   NaN  NaN    Thailand
# 839747  839748     12/8/2021     11/8/2021   ชาย   NaN  NaN    Thailand
# 839748  839749     12/8/2021     11/8/2021   ชาย   NaN  NaN    Thailand
# 839749  839750     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839750  839751     12/8/2021     11/8/2021   ชาย  37.0   ปี    Thailand
# 839751  839752     12/8/2021     11/8/2021   ชาย  24.0   ปี    Thailand
# 839752  839753     12/8/2021     11/8/2021   ชาย   NaN  NaN    Thailand
# 839753  839754     12/8/2021     11/8/2021   ชาย  33.0   ปี         NaN
# 839754  839755     12/8/2021     11/8/2021   ชาย  30.0   ปี    Thailand
# 839755  839756     12/8/2021     11/8/2021   ชาย  26.0   ปี    Thailand
# 839756  839757     12/8/2021     11/8/2021   ชาย  28.0   ปี    Thailand
# 839757  839758     12/8/2021     11/8/2021   ชาย  35.0   ปี         NaN
# 839758  839759     12/8/2021     11/8/2021   ชาย  23.0   ปี         NaN
# 839759  839760     12/8/2021     11/8/2021   ชาย  33.0   ปี    Thailand
# 839760  839761     12/8/2021     11/8/2021   ชาย  61.0   ปี         NaN
# 839761  839762     12/8/2021     11/8/2021   ชาย  23.0   ปี         NaN
# 839762  839763     12/8/2021     11/8/2021   ชาย  36.0   ปี         NaN
# 839763  839764     12/8/2021     11/8/2021   ชาย  64.0   ปี         NaN
# 839764  839765     12/8/2021     11/8/2021   ชาย  43.0   ปี         NaN
# 839765  839766     12/8/2021     11/8/2021   ชาย  53.0   ปี         NaN
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation              risk province_of_onset  \
# 839721             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839722             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839723             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839724             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839725             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839726             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839727             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839728             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839729             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839730             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839731             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839732             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839733             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839734             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839735             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839736             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839737             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839738             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839739             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839740             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839741             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839742                 ระนอง  ทัณฑสถาน/เรือนจำ             ระนอง
# 839743                 ระนอง  ทัณฑสถาน/เรือนจำ             ระนอง
# 839744              นราธิวาส  ทัณฑสถาน/เรือนจำ          นราธิวาส
# 839745              นราธิวาส  ทัณฑสถาน/เรือนจำ          นราธิวาส
# 839746              นราธิวาส  ทัณฑสถาน/เรือนจำ          นราธิวาส
# 839747              นราธิวาส  ทัณฑสถาน/เรือนจำ          นราธิวาส
# 839748              นราธิวาส  ทัณฑสถาน/เรือนจำ          นราธิวาส
# 839749              นราธิวาส  ทัณฑสถาน/เรือนจำ          นราธิวาส
# 839750              นราธิวาส  ทัณฑสถาน/เรือนจำ          นราธิวาส
# 839751              นราธิวาส  ทัณฑสถาน/เรือนจำ          นราธิวาส
# 839752              นราธิวาส  ทัณฑสถาน/เรือนจำ          นราธิวาส
# 839753              นราธิวาส  ทัณฑสถาน/เรือนจำ          นราธิวาส
# 839754                  สตูล  ทัณฑสถาน/เรือนจำ              สตูล
# 839755                  สตูล  ทัณฑสถาน/เรือนจำ              สตูล
# 839756                  สตูล  ทัณฑสถาน/เรือนจำ              สตูล
# 839757             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839758             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839759             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839760             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839761             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839762             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839763             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839764             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839765             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839766             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839767             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839768             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839769             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839770             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
#
#        district_of_onset
# 839721               NaN
# 839722               NaN
# 839723               NaN
# 839724               NaN
# 839725               NaN
# 839726               NaN
# 839727               NaN
# 839728               NaN
# 839729               NaN
# 839730               NaN
# 839731               NaN
# 839732               NaN
# 839733               NaN
# 839734               NaN
# 839735               NaN
# 839736               NaN
# 839737               NaN
# 839738               NaN
# 839739               NaN
# 839740               NaN
# 839741               NaN
# 839742               NaN
# 839743               NaN
# 839744               NaN
# 839745               NaN
# 839746               NaN
# 839747               NaN
# 839748               NaN
# 839749               NaN
# 839750               NaN
# 839751               NaN
# 839752               NaN
# 839753               NaN
# 839754               NaN
# 839755               NaN
# 839756               NaN
# 839757               NaN
# 839758               NaN
# 839759               NaN
# 839760               NaN
# 839761               NaN
# 839762               NaN
# 839763               NaN
# 839764               NaN
# 839765               NaN
# 839766               NaN
# 839767               NaN
# 839768               NaN
# 839769               NaN
# 839770               NaN

# %%
data_cases.iloc[-50:,[3,6,8]]
# Out:
#          sex nationality              risk
# 839721   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839722  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839723  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839724  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839725  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839726  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839727  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839728  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839729  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839730  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839731  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839732  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839733  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 839734  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839735  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839736  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839737  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839738  หญิง         NaN  ทัณฑสถาน/เรือนจำ
# 839739  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839740  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839741  หญิง    Thailand  ทัณฑสถาน/เรือนจำ
# 839742   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 839743   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839744   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 839745   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 839746   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839747   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839748   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839749   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839750   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839751   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839752   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839753   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 839754   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839755   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839756   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839757   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 839758   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 839759   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839760   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 839761   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 839762   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 839763   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 839764   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 839765   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 839766   ชาย         NaN  ทัณฑสถาน/เรือนจำ
# 839767   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839768   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839769   ชาย    Thailand  ทัณฑสถาน/เรือนจำ
# 839770   ชาย    Thailand  ทัณฑสถาน/เรือนจำ

# %% [markdown]
# # Descriptive Statistics of Data

# %%
data_cases.describe()
# Out:
#                  No.
# count  839771.000000
# mean   419886.000000
# std    242421.150791
# min         1.000000
# 25%    209943.500000
# 50%    419886.000000
# 75%    629828.500000
# max    839771.000000

# %% [markdown]
# # Missing Value
#
#
#
# *   Null
# *   NaN = Not a Number
# *   NA = Not available

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [839771 rows x 11 columns]

# %%
data_cases.isnull()
# Out:
#           No.  announce_date  Notified date    sex    age   Unit  nationality  \
# 0       False          False           True  False  False  False        False
# 1       False          False           True  False  False  False        False
# 2       False          False           True  False  False  False        False
# 3       False          False           True  False  False  False        False
# 4       False          False           True  False  False  False        False
# ...       ...            ...            ...    ...    ...    ...          ...
# 839766  False          False          False  False  False  False         True
# 839767  False          False          False  False  False  False        False
# 839768  False          False          False  False  False  False        False
# 839769  False          False          False  False  False  False        False
# 839770  False          False          False  False  False  False        False
#
#         province_of_isolation   risk  province_of_onset  district_of_onset
# 0                       False  False              False               True
# 1                       False  False              False               True
# 2                       False  False              False              False
# 3                       False  False              False               True
# 4                       False  False              False               True
# ...                       ...    ...                ...                ...
# 839766                  False  False              False               True
# 839767                  False  False              False               True
# 839768                  False  False              False               True
# 839769                  False  False              False               True
# 839770                  False  False              False               True
#
# [839771 rows x 11 columns]

# %%
data_cases.isnull().any()  # .any() คือ Or ในแนว columns
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases.isnull().any().any()
# Out:
# True

# %%
data_cases.isnull().all()  # .all() คือ and ในแนว columns
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# # Handling Missing Value 1 (ลบค่า missing )

# %%
data_cases.shape
# Out:
# (839771, 11)

# %%
data_cases_M1 = data_cases.dropna()

# %%
data_cases_M1.shape
# Out:
# (599988, 11)

# %% [markdown]
# size before drop = 1000
#
# size after drop = 10
#
# we lost 99% of data

# %%
print('size before drop = ',len(data_cases))
print('size after drop = ', len(data_cases_M1))
print('we lost ', ((len(data_cases)-len(data_cases_M1))/len(data_cases))*100, '% of data')
# Out:
# size before drop =  839771
# size after drop =  599988
# we lost  28.553379433202625 % of data

# %%
print(f'size before drop = {len(data_cases)}')
print('size after drop = ', len(data_cases_M1))
print(f'we lost {((len(data_cases)-len(data_cases_M1))/len(data_cases))*100:.2f}% of data')
# Out:
# size before drop = 839771
# size after drop =  599988
# we lost 28.55% of data

# %% [markdown]
# ## Handling Missing Value 1.5 (ลบค่า missing เฉพาะใน column ที่เราสนใจ)

# %%
data_cases_M15 = data_cases.dropna(subset=['Notified date', 'sex', 'age'])

# %%
data_cases_M15.shape
# Out:
# (733511, 11)

# %% [markdown]
# HW
#
# ```print``` ของ missing 1.5
#
# size before drop = 1000
#
# size after drop = 10
#
# we lost 99% of data
#
# now we have x% more data than handling_missing1

# %% [markdown]
# ## Handling Missing Value 2 แทนด้วยค่าที่เหมาะสมหรือสร้าง class ใหม่

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [839771 rows x 11 columns]

# %%
data_cases['age'] = data_cases['age'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-9915f89acf4e> in <cell line: 1>()
# ----> 1 data_cases['age'] = data_cases['age'].astype(float)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     350                     applied = b.apply(f, **kwargs)
#     351                 else:
# --> 352                     applied = getattr(b, f)(**kwargs)
#     353             except (TypeError, NotImplementedError):
#     354                 if not ignore_failures:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     524         values = self.values
#     525
# --> 526         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     527
#     528         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     297
#     298     try:
# --> 299         new_values = astype_array(values, dtype, copy=copy)
#     300     except (ValueError, TypeError):
#     301         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     228
#     229     else:
# --> 230         values = astype_nansafe(values, dtype, copy=copy)
#     231
#     232     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/astype.py in astype_nansafe(arr, dtype, copy, skipna)
#     168     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169         # Explicit copy, or required since NumPy can't view from / to object.
# --> 170         return arr.astype(dtype, copy=True)
#     171
#     172     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '55/664'

# %%
[i for i in data_cases['age'] if i=='55/664']
# Out:
# ['55/664']

# %%
data_cases['age'][data_cases['age']=='55/664'] = np.nan
# Out:
# <ipython-input-30-44f75530b411>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cases['age'][data_cases['age']=='55/664'] = np.nan

# %%
[i for i in data_cases['age'] if i=='55/664']
# Out:
# []

# %%
data_cases['age'] = data_cases['age'].astype(float)

# %%
data_cases['age'].describe()
# Out:
# count    763605.000000
# mean         35.700109
# std          16.597799
# min           0.750000
# 25%          24.000000
# 50%          34.000000
# 75%          46.000000
# max         440.000000
# Name: age, dtype: float64

# %%
data_cases['age'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 839766    False
# 839767    False
# 839768    False
# 839769    False
# 839770    False
# Name: age, Length: 839771, dtype: bool

# %%
data_cases['age'].isna().sum()
# Out:
# 76166

# %%
data_cases['age'].mean() ## ถ้า function ไม่ได้ป้องกัน data ที่มี missing ไว้
# Out:
# 35.70010851159959

# %%
data_cases[['Notified date']] = data_cases[['Notified date']].fillna('99/99/9999')

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 2            3     22/1/2020    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020    99/99/9999   ชาย  68.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [839771 rows x 11 columns]

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ### ดู column unit

# %%
data_cases['Unit']
# Out:
# 0         ปี
# 1         ปี
# 2         ปี
# 3         ปี
# 4         ปี
#           ..
# 839766    ปี
# 839767    ปี
# 839768    ปี
# 839769    ปี
# 839770    ปี
# Name: Unit, Length: 839771, dtype: object

# %%
set(data_cases['Unit']) ## หา unique values
# Out:
# {' วัน', ' เดือน', nan, 'ปี', 'วัน', 'เดือน'}

# %%
data_cases["nationality"][data_cases["nationality"] == "ลาว"] = "Laos"
data_cases["nationality"][data_cases["nationality"] == "Laotian / Lao"] = "Laos"
data_cases["nationality"][data_cases["nationality"] == "lao"] = "Laos"
data_cases["nationality"][data_cases["nationality"] == "Lao"] = "Laos"
data_cases["nationality"][data_cases["nationality"] == "laotian/Lao"] = "Laos"
data_cases["nationality"][data_cases["nationality"] == "laos"] = "Laos"
# Out:
# <ipython-input-52-213d9ba131c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cases["nationality"][data_cases["nationality"] == "ลาว"] = "Laos"
# <ipython-input-52-213d9ba131c1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cases["nationality"][data_cases["nationality"] == "Laotian / Lao"] = "Laos"
# <ipython-input-52-213d9ba131c1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cases["nationality"][data_cases["nationality"] == "lao"] = "Laos"
# <ipython-input-52-213d9ba131c1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cases["nationality"][data_cases["nationality"] == "Lao"] = "Laos"
# <ipython-input-52-213d9ba131c1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cases["nationality"][data_cases["nationality"] == "laotian/Lao"] = "Laos"
# <ipython-input-52-213d9ba131c1>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cases["nationality"][data_cases["nationality"] == "laos"] = "Laos"

# %%
data_cases['Unit'][data_cases['Unit'] ==  ' วัน'] = 'วัน'
data_cases['Unit'][data_cases['Unit'] ==  ' เดือน'] = 'เดือน'
# Out:
# <ipython-input-51-ddee90b9f874>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cases['Unit'][data_cases['Unit'] ==  ' วัน'] = 'วัน'
# <ipython-input-51-ddee90b9f874>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cases['Unit'][data_cases['Unit'] ==  ' เดือน'] = 'เดือน'

# %% [markdown]
# ## [PD] วิธีเลือก record โดยการกำหนดค่า

# %%
data_cases[data_cases['Unit']=='วัน']
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 19706    19707      2/2/2021      1/2/2021  หญิง  26.0  วัน       Burma
# 23791    23792     10/2/2021      9/2/2021  หญิง   2.0  วัน       Burma
# 40961    40962     18/4/2021     17/4/2021  หญิง   3.0  วัน    Thailand
# 57745    57746     27/4/2021     26/4/2021  หญิง  10.0  วัน    Thailand
# 65454    65455      1/5/2021     30/4/2021   ชาย   7.0  วัน    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 786915  786916     10/8/2021      9/8/2021  หญิง   8.0  วัน         NaN
# 787832  787833     10/8/2021      9/8/2021   ชาย  27.0  วัน    Thailand
# 789523  789524     10/8/2021      9/8/2021   ชาย  28.0  วัน    Thailand
# 816034  816035     11/8/2021     10/8/2021   ชาย   1.0  วัน    Thailand
# 817116  817117     12/8/2021     11/8/2021   ชาย  27.0  วัน    Thailand
#
#        province_of_isolation                                         risk  \
# 19706              สมุทรสาคร                            Cluster สมุทรสาคร
# 23791              สมุทรสาคร                            Cluster สมุทรสาคร
# 40961             นครราชสีมา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 57745             นครราชสีมา                         อยู่ระหว่างการสอบสวน
# 65454          กรุงเทพมหานคร  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 786915               ขอนแก่น  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 787832               หนองคาย                                        อื่นๆ
# 789523              ศรีสะเกษ                                        อื่นๆ
# 816034           สมุทรปราการ  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 817116                  น่าน                                        อื่นๆ
#
#        province_of_onset district_of_onset
# 19706          สมุทรสาคร    เมืองสมุทรสาคร
# 23791          สมุทรสาคร    เมืองสมุทรสาคร
# 40961         นครราชสีมา           เสิงสาง
# 57745                NaN               NaN
# 65454      กรุงเทพมหานคร          ปากเกร็ด
# ...                  ...               ...
# 786915           ขอนแก่น             เมือง
# 787832           หนองคาย             เมือง
# 789523     กรุงเทพมหานคร               NaN
# 816034       สมุทรปราการ            บางบ่อ
# 817116               NaN               NaN
#
# [139 rows x 11 columns]

# %%
data_cases[data_cases['Unit']==' วัน']
# Out:
#            No. announce_date Notified date  sex   age  Unit nationality  \
# 138777  138778     27/5/2021     26/5/2021  ชาย  23.0   วัน     Burmese
#
#        province_of_isolation                                         risk  \
# 138777           สมุทรปราการ  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#        province_of_onset district_of_onset
# 138777       สมุทรปราการ            บางพลี

# %% [markdown]
# ```python
# data_frame[list_of_logics] #list_of_logics มีขนาดเท่ากับจำนวน record ของ data_frame
# ```

# %%
data_cases['Unit']=='วัน'  # list_of_logics
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 839766    False
# 839767    False
# 839768    False
# 839769    False
# 839770    False
# Name: Unit, Length: 839771, dtype: bool

# %%
data_cases[data_cases['Unit']=='วัน'].sort_values(by='age')
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 770185  770186      9/8/2021      8/8/2021  หญิง   1.0  วัน    Thailand
# 771397  771398      9/8/2021      8/8/2021  หญิง   1.0  วัน    Thailand
# 611316  611317      1/8/2021     31/7/2021   ชาย   1.0  วัน    Thailand
# 597624  597625      1/8/2021     31/7/2021   ชาย   1.0  วัน     Burmese
# 565946  565947     30/7/2021     29/7/2021  หญิง   1.0  วัน     Burmese
# ...        ...           ...           ...   ...   ...  ...         ...
# 291193  291194      6/7/2021      5/7/2021  หญิง  28.0  วัน    Thailand
# 789523  789524     10/8/2021      9/8/2021   ชาย  28.0  วัน    Thailand
# 530438  530439     28/7/2021     27/7/2021  หญิง  29.0  วัน    Thailand
# 443530  443531     22/7/2021     21/7/2021   ชาย  29.0  วัน     Burmese
# 286044  286045      5/7/2021      4/7/2021   ชาย  29.0  วัน   Cambodian
#
#        province_of_isolation                                         risk  \
# 770185           อุบลราชธานี                                        อื่นๆ
# 771397          สุราษฎร์ธานี  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 611316                 สงขลา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 597624                   ตาก  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 565946             กาญจนบุรี                         อยู่ระหว่างการสอบสวน
# ...                      ...                                          ...
# 291193           สมุทรปราการ                         อยู่ระหว่างการสอบสวน
# 789523              ศรีสะเกษ                                        อื่นๆ
# 530438             สมุทรสาคร  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 443530                นครปฐม  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 286044                ชลบุรี  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#        province_of_onset district_of_onset
# 770185             ระยอง               NaN
# 771397      สุราษฎร์ธานี          เวียงสระ
# 611316             สงขลา           สิงหนคร
# 597624               ตาก             พบพระ
# 565946         กาญจนบุรี           ท่ามะกา
# ...                  ...               ...
# 291193       สมุทรปราการ    พระสมุทรเจดีย์
# 789523     กรุงเทพมหานคร               NaN
# 530438         สมุทรสาคร    เมืองสมุทรสาคร
# 443530            นครปฐม           สามพราน
# 286044            ชลบุรี           ศรีราชา
#
# [139 rows x 11 columns]

# %% [markdown]
# Quiz 10
# หา records ต่อไปนี้
#
# ~records ที่ กักตัวที่ขอนแก่น~ Oil
#
# ~records ที่ กักตัวที่ ขอนแก่น+โคราช+อุดร~ Kie
#
# ~records ที่ เป็นผู้หญิงที่พบเชื้อที่ กทม~ Kie
#
# ~records ที่ เป็นผู้ชาย อายุ 18-22 ปี ที่กักตัวที่เชียงใหม่~ Nicha

# %% [markdown]
# records ที่ กักตัวที่ขอนแก่น

# %%
data_cases[data_cases['province_of_isolation']=='ขอนแก่น']
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 181        182     18/3/2020     15/3/2020   ชาย  33.0   ปี    Thailand
# 463        464     22/3/2020     21/3/2020  หญิง  36.0   ปี    Thailand
# 1467      1468     30/3/2020     26/3/2020   ชาย  19.0   ปี    Thailand
# 1971      1972      3/4/2020     31/3/2020  หญิง  70.0   ปี    Thailand
# 2638      2639     15/4/2020     14/4/2020  หญิง  63.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 839669  839670     12/8/2021     11/8/2021   ชาย  46.0   ปี    Thailand
# 839670  839671     12/8/2021     11/8/2021   ชาย  58.0   ปี    Thailand
# 839671  839672     12/8/2021     11/8/2021   ชาย  30.0   ปี    Thailand
# 839672  839673     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
# 839673  839674     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
#
#        province_of_isolation                                           risk  \
# 181                  ขอนแก่น                                        สนามมวย
# 463                  ขอนแก่น    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1467                 ขอนแก่น                  คนไทยเดินทางกลับจากต่างประเทศ
# 1971                 ขอนแก่น  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2638                 ขอนแก่น                  สัมผัสผู้เดินทางจากต่างประเทศ
# ...                      ...                                            ...
# 839669               ขอนแก่น                               ทัณฑสถาน/เรือนจำ
# 839670               ขอนแก่น                               ทัณฑสถาน/เรือนจำ
# 839671               ขอนแก่น                               ทัณฑสถาน/เรือนจำ
# 839672               ขอนแก่น                               ทัณฑสถาน/เรือนจำ
# 839673               ขอนแก่น                               ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 181              ขอนแก่น             เมือง
# 463              ขอนแก่น             เมือง
# 1467             ขอนแก่น             เมือง
# 1971             ขอนแก่น             เมือง
# 2638             ขอนแก่น            น้ำพอง
# ...                  ...               ...
# 839669           ขอนแก่น               NaN
# 839670           ขอนแก่น               NaN
# 839671           ขอนแก่น               NaN
# 839672           ขอนแก่น               NaN
# 839673           ขอนแก่น               NaN
#
# [6760 rows x 11 columns]

# %% [markdown]
# records ที่ กักตัวที่ ขอนแก่น+โคราช+อุดร

# %%
data_cases[(data_cases['province_of_isolation']=='ขอนแก่น') | (data_cases['province_of_isolation']=='นครราชสีมา') |
           (data_cases['province_of_isolation']=='อุดรธานี')]
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 181        182     18/3/2020     15/3/2020   ชาย  33.0   ปี    Thailand
# 189        190     18/3/2020     16/3/2020   ชาย  57.0   ปี    Thailand
# 207        208     18/3/2020     16/3/2020  หญิง  30.0   ปี    Thailand
# 212        213     18/3/2020     14/3/2020  หญิง  22.0   ปี    Thailand
# 284        285     20/3/2020     17/3/2020   ชาย  42.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 839669  839670     12/8/2021     11/8/2021   ชาย  46.0   ปี    Thailand
# 839670  839671     12/8/2021     11/8/2021   ชาย  58.0   ปี    Thailand
# 839671  839672     12/8/2021     11/8/2021   ชาย  30.0   ปี    Thailand
# 839672  839673     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
# 839673  839674     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
#
#        province_of_isolation                                           risk  \
# 181                  ขอนแก่น                                        สนามมวย
# 189               นครราชสีมา                                        สนามมวย
# 207               นครราชสีมา                                    สถานบันเทิง
# 212               นครราชสีมา  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 284               นครราชสีมา                                        สนามมวย
# ...                      ...                                            ...
# 839669               ขอนแก่น                               ทัณฑสถาน/เรือนจำ
# 839670               ขอนแก่น                               ทัณฑสถาน/เรือนจำ
# 839671               ขอนแก่น                               ทัณฑสถาน/เรือนจำ
# 839672               ขอนแก่น                               ทัณฑสถาน/เรือนจำ
# 839673               ขอนแก่น                               ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 181              ขอนแก่น             เมือง
# 189           นครราชสีมา             พิมาย
# 207        กรุงเทพมหานคร               NaN
# 212           นครราชสีมา       วังน้ำเขียว
# 284           นครราชสีมา   เมืองนครราชสีมา
# ...                  ...               ...
# 839669           ขอนแก่น               NaN
# 839670           ขอนแก่น               NaN
# 839671           ขอนแก่น               NaN
# 839672           ขอนแก่น               NaN
# 839673           ขอนแก่น               NaN
#
# [22887 rows x 11 columns]

# %% [markdown]
# records ที่ เป็นผู้หญิงที่พบเชื้อที่ กทม

# %%
data_cases[(data_cases['province_of_onset']=='กรุงเทพมหานคร') & (data_cases['sex']=='หญิง')]
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# 5            6     25/1/2020    99/99/9999  หญิง  33.0   ปี       China
# 6            7     26/1/2020    99/99/9999  หญิง  57.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839380  839381     12/8/2021     11/8/2021  หญิง  53.0   ปี    Thailand
# 839386  839387     12/8/2021     11/8/2021  หญิง  78.0   ปี    Thailand
# 839391  839392     12/8/2021     11/8/2021  หญิง  83.0   ปี    Thailand
# 839393  839394     12/8/2021     11/8/2021  หญิง  43.0   ปี    Thailand
# 839394  839395     12/8/2021     11/8/2021  หญิง  74.0   ปี    Thailand
#
#        province_of_isolation  \
# 0              กรุงเทพมหานคร
# 1              กรุงเทพมหานคร
# 4                    นนทบุรี
# 5              กรุงเทพมหานคร
# 6              กรุงเทพมหานคร
# ...                      ...
# 839380         กรุงเทพมหานคร
# 839386         กรุงเทพมหานคร
# 839391         กรุงเทพมหานคร
# 839393         กรุงเทพมหานคร
# 839394         กรุงเทพมหานคร
#
#                                                     risk province_of_onset  \
# 0                       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1                       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4                       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 5                       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 6                       คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# ...                                                  ...               ...
# 839380  การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน     กรุงเทพมหานคร
# 839386       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     กรุงเทพมหานคร
# 839391     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว     กรุงเทพมหานคร
# 839393     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว     กรุงเทพมหานคร
# 839394     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว     กรุงเทพมหานคร
#
#        district_of_onset
# 0                    NaN
# 1                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# ...                  ...
# 839380           บางกะปิ
# 839386         คลองสามวา
# 839391             วัฒนา
# 839393            ประเวศ
# 839394            ธนบุรี
#
# [89218 rows x 11 columns]

# %% [markdown]
# records ที่ เป็นผู้ชาย อายุ 18-22 ปี ที่กักตัวที่เชียงใหม่

# %%
data_cases[(data_cases['province_of_isolation']=='เชียงใหม่') &
           (data_cases['sex']=='ชาย') &
           (data_cases['age']>=18) &
           (data_cases['age']<=22)].sort_values(by='age')
# Out:
#          No. announce_date Notified date  sex   age Unit nationality  \
# 56211  56212     26/4/2021     25/4/2021  ชาย  18.0   ปี    Thailand
# 37293  37294     15/4/2021     14/4/2021  ชาย  18.0   ปี    Thailand
# 54198  54199     25/4/2021     24/4/2021  ชาย  18.0   ปี         NaN
# 54121  54122     25/4/2021     24/4/2021  ชาย  18.0   ปี         NaN
# 66258  66259      1/5/2021     30/4/2021  ชาย  18.0   ปี    Thailand
# ...      ...           ...           ...  ...   ...  ...         ...
# 54251  54252     25/4/2021     24/4/2021  ชาย  22.0   ปี         NaN
# 34486  34487     13/4/2021     12/4/2021  ชาย  22.0   ปี         NaN
# 34481  34482     13/4/2021     12/4/2021  ชาย  22.0   ปี         NaN
# 52549  52550     24/4/2021     23/4/2021  ชาย  22.0   ปี    Thailand
# 37450  37451     15/4/2021     14/4/2021  ชาย  22.0   ปี    Thailand
#
#       province_of_isolation                                              risk  \
# 56211             เชียงใหม่       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 37293             เชียงใหม่  การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน
# 54198             เชียงใหม่                                               NaN
# 54121             เชียงใหม่                                               NaN
# 66258             เชียงใหม่       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                     ...                                               ...
# 54251             เชียงใหม่                                               NaN
# 34486             เชียงใหม่  การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน
# 34481             เชียงใหม่  การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน
# 52549             เชียงใหม่                              อยู่ระหว่างการสอบสวน
# 37450             เชียงใหม่  การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน
#
#       province_of_onset district_of_onset
# 56211         เชียงใหม่    เมืองเชียงใหม่
# 37293         เชียงใหม่         ดอยสะเก็ด
# 54198               NaN            แม่อาย
# 54121               NaN    เมืองเชียงใหม่
# 66258         เชียงใหม่    เมืองเชียงใหม่
# ...                 ...               ...
# 54251               NaN    เมืองเชียงใหม่
# 34486         เชียงใหม่               NaN
# 34481         เชียงใหม่               NaN
# 52549         เชียงใหม่             หางดง
# 37450         เชียงใหม่    เมืองเชียงใหม่
#
# [456 rows x 11 columns]

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(data_cases['Unit'].dropna())
# Out:
# (array([7.6117e+05, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         2.4360e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.4000e+02]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
data_cases[['Unit']] = data_cases[['Unit']].fillna('ปี')

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                     False
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases[['nationality']] = data_cases[['nationality']].fillna('ไทย?')

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 2            3     22/1/2020    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020    99/99/9999   ชาย  68.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [839771 rows x 11 columns]

# %% [markdown]
# ## Handling Missing Value 3 แทนด้วยค่าด้วยค่ากลาง

# %%
data_cases[['age']] = data_cases[['age']].fillna(data_cases['age'].mean())

# %%
data_cases[['age']].describe()
# Out:
#                  age
# count  839771.000000
# mean       35.700109
# std        15.827212
# min         0.750000
# 25%        25.000000
# 50%        35.700109
# 75%        45.000000
# max       440.000000

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases[['sex']].dropna().mode()
# Out:
#     sex
# 0  หญิง

# %%
data_cases[['sex']].dropna().mode().iloc[0,0]
# Out:
# 'หญิง'

# %%
data_cases[['sex']] = data_cases[['sex']].fillna(data_cases[['sex']].dropna().mode().iloc[0,0])
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %% [markdown]
# ## Loop [PD]

# %%
for i in range(10):
    print(data_cases.iloc[i,:])
    print('------------------new line---------------')
# Out:
# No.                                                     1
# announce_date                                   12/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  61.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 0, dtype: object
# ------------------new line---------------
# No.                                                     2
# announce_date                                   17/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  74.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 1, dtype: object
# ------------------new line---------------
# No.                                                     3
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  73.0
# Unit                                                   ปี
# nationality                                      Thailand
# province_of_isolation                              นครปฐม
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                  นครปฐม
# district_of_onset                                   เมือง
# Name: 2, dtype: object
# ------------------new line---------------
# No.                                                     4
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                  68.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 3, dtype: object
# ------------------new line---------------
# No.                                                     5
# announce_date                                   24/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  66.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 4, dtype: object
# ------------------new line---------------
# No.                                                     6
# announce_date                                   25/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  33.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 5, dtype: object
# ------------------new line---------------
# No.                                                     7
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  57.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 6, dtype: object
# ------------------new line---------------
# No.                                                     8
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  73.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                     ประจวบคีรีขันธ์
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                         ประจวบคีรีขันธ์
# district_of_onset                                  หัวหิน
# Name: 7, dtype: object
# ------------------new line---------------
# No.                                                     9
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                  63.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 8, dtype: object
# ------------------new line---------------
# No.                                                    10
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  28.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                 นนทบุรี
# district_of_onset                                     NaN
# Name: 9, dtype: object
# ------------------new line---------------

# %%
for record in data_cases.iloc[:10,:].iterrows():
    print(record)
    print('------------------new line---------------')
# Out:
# (0, No.                                                     1
# announce_date                                   12/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  61.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 0, dtype: object)
# ------------------new line---------------
# (1, No.                                                     2
# announce_date                                   17/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  74.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 1, dtype: object)
# ------------------new line---------------
# (2, No.                                                     3
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  73.0
# Unit                                                   ปี
# nationality                                      Thailand
# province_of_isolation                              นครปฐม
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                  นครปฐม
# district_of_onset                                   เมือง
# Name: 2, dtype: object)
# ------------------new line---------------
# (3, No.                                                     4
# announce_date                                   22/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                  68.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 3, dtype: object)
# ------------------new line---------------
# (4, No.                                                     5
# announce_date                                   24/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  66.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 4, dtype: object)
# ------------------new line---------------
# (5, No.                                                     6
# announce_date                                   25/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  33.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 5, dtype: object)
# ------------------new line---------------
# (6, No.                                                     7
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  57.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 6, dtype: object)
# ------------------new line---------------
# (7, No.                                                     8
# announce_date                                   26/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  73.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                     ประจวบคีรีขันธ์
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                         ประจวบคีรีขันธ์
# district_of_onset                                  หัวหิน
# Name: 7, dtype: object)
# ------------------new line---------------
# (8, No.                                                     9
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                   ชาย
# age                                                  63.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                       กรุงเทพมหานคร
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                           กรุงเทพมหานคร
# district_of_onset                                     NaN
# Name: 8, dtype: object)
# ------------------new line---------------
# (9, No.                                                    10
# announce_date                                   28/1/2020
# Notified date                                  99/99/9999
# sex                                                  หญิง
# age                                                  28.0
# Unit                                                   ปี
# nationality                                         China
# province_of_isolation                             นนทบุรี
# risk                     คนต่างชาติเดินทางมาจากต่างประเทศ
# province_of_onset                                 นนทบุรี
# district_of_onset                                     NaN
# Name: 9, dtype: object)
# ------------------new line---------------

# %% [markdown]
# ## เราสามารถกำหนดค่าให้กับตารางทีละ column หรือสร้าง
# ## column ใหม่ให้กับตาราง ได้โดยใช้ list ที่มีจำนวนเท่ากับจำนวน record

# %%
data_cases['new col'] = list(range(data_cases.shape[0]))

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 2            3     22/1/2020    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020    99/99/9999   ชาย  68.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset  new col
# 0          กรุงเทพมหานคร               NaN        0
# 1          กรุงเทพมหานคร               NaN        1
# 2                 นครปฐม             เมือง        2
# 3          กรุงเทพมหานคร               NaN        3
# 4          กรุงเทพมหานคร               NaN        4
# ...                  ...               ...      ...
# 839766         กาญจนบุรี               NaN   839766
# 839767         กาญจนบุรี               NaN   839767
# 839768         กาญจนบุรี               NaN   839768
# 839769         กาญจนบุรี               NaN   839769
# 839770         กาญจนบุรี               NaN   839770
#
# [839771 rows x 12 columns]

# %% [markdown]
# # แก้ missing ใน province_of_isolation เติมค่าของ onset ใน isolation ก่อนจะเติมค่า mode

# %%
new_p_iso = list()

for row in data_cases.iterrows():
    if pd.isna(row[1]['province_of_isolation']):
        if pd.isna(row[1]['province_of_onset']) == False:
            new_p_iso.append(row[1]['province_of_onset'])
        else:
            new_p_iso.append(data_cases[['province_of_isolation']].dropna().mode().iloc[0,0])
    else:
        new_p_iso.append(row[1]['province_of_isolation'])

# %%
len(new_p_iso)
# Out:
# 839771

# %%
data_cases['province_of_isolation'] = new_p_iso

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 2            3     22/1/2020    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020    99/99/9999   ชาย  68.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [839771 rows x 11 columns]

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_cases2 = pd.read_csv(os.path.join('covid19-Thailand/confirmed-cases.csv'))
# Out:
# /var/folders/_f/br5bc56d1cd52nkftmn0k09w0000gn/T/ipykernel_40436/2163999757.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_cases2 = pd.read_csv(os.path.join('covid19-Thailand/confirmed-cases.csv'))

# %%
data_cases2[pd.isna(data_cases2['province_of_isolation'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-fe4a1724fdb0> in <cell line: 1>()
# ----> 1 data_cases2[pd.isna(data_cases2['province_of_isolation'])]
#
# NameError: name 'data_cases2' is not defined

# %%
data_cases[pd.isna(data_cases2['province_of_isolation'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-345015c12be9> in <cell line: 1>()
# ----> 1 data_cases[pd.isna(data_cases2['province_of_isolation'])]
#
# NameError: name 'data_cases2' is not defined

# %% [markdown]
# ## Handling Missing Value 4 แทนด้วยค่าด้วยค่ากลางของกลุ่ม

# %%
data_cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
risk_list = list(set(data_cases['risk']))
print(risk_list)
# Out:
# ['ผู้ป่วย กรุงเทพมหานคร', 'อื่น ๆ', 'อาชีพเสี่ยง', 'สัมผัสผู้ป่วยที่ติดโควิด', 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้', 'พิธีกรรมทางศาสนา', 'สัมผัสใกล้ชิดผู้ป่วยยืนยันก่อนหน้า', 'สัมผัสผู้ป่วยยืนยัน', 'Cluster ตราด ', 'ผู้ติดเชื้อในประเทศ', 'สัมผัสสามีสะอาด เขตบ้าน (รพ.มหาชัย 2)', 'รอประสาน', 'ทัณฑสถาน/เรือนจำ', 'Cluster บางแค', 'อยู่ระหว่างสอบสวน', 'Cluster ตลาดพรพัฒน์', 'Cluster โรงงานทำขนม บางขุนเทียน', 'ค้นหาเชิงรุก', 'Cluster บริษัทศรีสวัสดิ์', 'มาจากพื้นที่เสียง จ.ปทุมธานี', 'มาจากพื้นที่เสี่ยง', 'พื้นที่เสียง', 'ระหว่างสอบสวน', 'สัมผัสผู้ป่วยยืนยัน ภายในครอบครัว/ชุมชน/เพื่อน', 'สัมผัสผู้ป่วยยืนยันเพื่อนร่วมงาน', 'ACF เคหะหลักสี่', 'Cluster บ่อนเทพารักษ์', 'อื่นๆ', 'Cluster โรงงาน Big Star', nan, 'Cluster ระยอง', 'ACF สนามกีฬาไทย-ญี่ปุ่น', 'ไปแหล่งชุมชน/สถานที่คนหนาแน่น', 'เดินทางมาจากพื้นที่เสี่ยงที่มีการระบาดของโรค', 'รับจ้างขนของที่ตลาดท่ายาง', '2.สัมผัสผู้ติดเชื้อ', 'Cluster ตลาดสี่มุมเมือง', "Cluster Memory 90's กรุงเทพมหานคร", 'Cluster จันทบุรี', 'ผู้เดินทางมาจากพื้นที่เสี่ยง กรุงเทพมหานคร', 'Cluster จันทบุรี (ชาวกินี )', 'Cluster ปากช่อง', 'ไปสถานที่เสี่ยง เช่น ตลาด สถานที่ชุมชน', 'Cluster ห้างแสงทอง (สายล่าง)', 'Cluster โรงงาน QPP ประจวบฯ', 'อื่น', 'ผับหัวหิน', 'ACF สนามกีฬาธูปะเตมีย์', 'สัมผัสผู้ป่วยยืนยัน \n  อยู่ระหว่างสอบสวน', 'ระบุไม่ได้', 'Cluster ตราด', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AOQ', 'สัมผัสผู้เดินทางจากต่างประเทศ', 'คนไทยเดินทางมาจากต่างประเทศ', 'ACF สีลม', 'Cluster จันทบุรี (ชาวกินี)', 'คนไทยเดินทางกลับจากต่างประเทศ', 'อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น', 'Cluster ตลาดบางแค', 'สน.วัดพระยาไกร', 'Cluster เครือคัสเซ่อร์พีคโฮลดิ้ง (CPG,CPH)', 'Cluster สมุทรปราการ ตลาดเคหะบางพลี', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ', 'แรงงานต่างด้าวตรวจก่อนขึ้นทะเบียน', 'Cluster Icon siam', 'คนต่างชาติเดินทางมาจากต่างประเทศ', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า HQ/AHQ', 'ระหว่างการสอบสวนโรค', 'ไปยัง/มาจาก พื้นที่ระบาดกรุงเทพมหานคร', 'cluster ชลบุรี\n(อยู่ระหว่างการสอบสวน)', 'อยู่ระหว่างการสอบสวน', 'Cluster สถานบันเทิงย่านทองหล่อ', 'Cluster ชลบุรี', 'ศูนย์กักกัน ผู้ต้องกัก', 'เดินทางมาจากพื้นที่เสี่ยง จ.กรุงเทพฯ จอมทอง', 'Cluster สมุทรสาคร', 'Cluster ผับ Thonglor', 'ไปยังพื้นที่ที่มีการระบาด', 'สถานที่ทำงาน', 'คนไทยมาจากพื้นที่เสี่ยง', 'Sandbox', 'การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน', 'สัมผัสผู้ติดเชื้อยืนยัน\n  อยู่ระหว่างสอบสวน', 'สัมผัสใกล้ชิดผู้ป่วยยันยันก่อนหน้า', 'Cluster บ่อนพัทยา/ชลบุรี', 'ผู้ป่วย PUI', 'Cluster โรงงาน standard can', 'ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว', 'สถานบันเทิง', 'ปอดอักเสบ (Pneumonia)', 'ปอดอักเสบ Pneumonia', 'Cluster มหาสารคาม', 'ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต', 'สนามมวย', ' Samui plus', 'ACF รองเมือง', 'ไปเที่ยวสถานบันเทิงในอุบลที่พบการระบาดของโรค Ubar', 'Cluster คลองเตย', 'เดินทางมาจากพื้นที่จังหวัดเสี่ยง', 'เดินทางมาจากพื้นที่มีการระบาดของโรค', 'ตรวจสุขภาพแรงงานต่างด้าว', 'อิ่นๆ', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า OQ', 'มาจากพื้นที่เสี่ยง จ.ปทุมธานี', '10.อื่นๆ', 'สัมผัสผู้ป่วยยืนยัน อยู่ระหว่างสอบสวน', 'สัมผัสในสถานพยาบาล', 'Cluster จนท. สนามบินสุวรรณภูมิ', 'State Quarantine', 'ตลาด', 'Cluster ชลบุรี โรงเบียร์ 90', 'ตรวจก่อนทำหัตถการ', 'Cluster ชลบุรี บริษัทไดกิ้น', 'อยู่ระหว่างการสอบสวน\n', 'Cluster ตลาดบางพลี', 'ร้านอาหาร', 'สัมผัสผู้ป่วยยืนยัน (ยังไม่สามารถระบุได้)', 'Cluster งานมอเตอร์ โชว์', 'SHUI', 'Cluster New Jazz กรุงเทพมหานคร', 'Cluster ตลาดนนทบุรี', 'Samui plus', 'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AQ', 'สัมผัสผู้ติดเชื้อยืนยัน\nอยู่ระหว่างสอบสวน', 'Cluster The Lounge Salaya', 'Cluster สมุทรปราการ GRP Hightech', 'บุคลากรด้านการแพทย์และสาธารณสุข', 'Cluster บ่อนไก่อ่างทอง', 'Cluster สมุทรปราการ (โรงงาน บริษัทเมทัล โปรดักส์)']

# %% [markdown]
# ทำของขอนแก่น

# %%
dataKK = data_cases[data_cases['province_of_onset']=='ขอนแก่น']

# %%
dataKK[['risk']] = dataKK[['risk']].fillna(dataKK[['risk']].dropna().mode().iloc[0,0])
# Out:
# <ipython-input-96-e5b7f394dd40>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataKK[['risk']] = dataKK[['risk']].fillna(dataKK[['risk']].dropna().mode().iloc[0,0])

# %%
dataKK
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 181        182     18/3/2020     15/3/2020   ชาย  33.0   ปี    Thailand
# 463        464     22/3/2020     21/3/2020  หญิง  36.0   ปี    Thailand
# 1467      1468     30/3/2020     26/3/2020   ชาย  19.0   ปี    Thailand
# 1971      1972      3/4/2020     31/3/2020  หญิง  70.0   ปี    Thailand
# 2638      2639     15/4/2020     14/4/2020  หญิง  63.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 839669  839670     12/8/2021     11/8/2021   ชาย  46.0   ปี    Thailand
# 839670  839671     12/8/2021     11/8/2021   ชาย  58.0   ปี    Thailand
# 839671  839672     12/8/2021     11/8/2021   ชาย  30.0   ปี    Thailand
# 839672  839673     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
# 839673  839674     12/8/2021     11/8/2021   ชาย  20.0   ปี    Thailand
#
#        province_of_isolation                                           risk  \
# 181                  ขอนแก่น                                        สนามมวย
# 463                  ขอนแก่น    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1467                 ขอนแก่น                  คนไทยเดินทางกลับจากต่างประเทศ
# 1971                 ขอนแก่น  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2638                 ขอนแก่น                  สัมผัสผู้เดินทางจากต่างประเทศ
# ...                      ...                                            ...
# 839669               ขอนแก่น                               ทัณฑสถาน/เรือนจำ
# 839670               ขอนแก่น                               ทัณฑสถาน/เรือนจำ
# 839671               ขอนแก่น                               ทัณฑสถาน/เรือนจำ
# 839672               ขอนแก่น                               ทัณฑสถาน/เรือนจำ
# 839673               ขอนแก่น                               ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 181              ขอนแก่น             เมือง
# 463              ขอนแก่น             เมือง
# 1467             ขอนแก่น             เมือง
# 1971             ขอนแก่น             เมือง
# 2638             ขอนแก่น            น้ำพอง
# ...                  ...               ...
# 839669           ขอนแก่น               NaN
# 839670           ขอนแก่น               NaN
# 839671           ขอนแก่น               NaN
# 839672           ขอนแก่น               NaN
# 839673           ขอนแก่น               NaN
#
# [5415 rows x 11 columns]

# %%
dataKK[['risk']].dropna().mode().iloc[0,0]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %%
dataKK.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset         True
# dtype: bool

# %%
dataCN = data_cases[data_cases['province_of_onset']=='ชลบุรี']

# %%
dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# Out:
# <ipython-input-101-61c7282d7081>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])

# %%
dataCN
# Out:
#            No. announce_date Notified date  sex   age Unit nationality  \
# 31          32      8/2/2020    99/99/9999  ชาย  24.0   ปี    Thailand
# 43          44      5/3/2020    99/99/9999  ชาย  29.0   ปี       Italy
# 44          45      5/3/2020    99/99/9999  ชาย  41.0   ปี    Thailand
# 154        155     17/3/2020    99/99/9999  ชาย  61.0   ปี    Thailand
# 222        223     19/3/2020    99/99/9999  ชาย  63.0   ปี    Thailand
# ...        ...           ...           ...  ...   ...  ...         ...
# 839468  839469     12/8/2021     11/8/2021  ชาย  29.0   ปี    Thailand
# 839469  839470     12/8/2021     11/8/2021  ชาย  34.0   ปี    Thailand
# 839470  839471     12/8/2021     11/8/2021  ชาย  21.0   ปี    Thailand
# 839471  839472     12/8/2021     11/8/2021  ชาย  30.0   ปี    Thailand
# 839472  839473     12/8/2021     11/8/2021  ชาย  35.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 31                    ชลบุรี                  State Quarantine
# 43                    ชลบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# 44                    ชลบุรี     คนไทยเดินทางกลับจากต่างประเทศ
# 154                   ชลบุรี                           สนามมวย
# 222                   ชลบุรี                           สนามมวย
# ...                      ...                               ...
# 839468                ชลบุรี                  ทัณฑสถาน/เรือนจำ
# 839469                ชลบุรี                  ทัณฑสถาน/เรือนจำ
# 839470                ชลบุรี                  ทัณฑสถาน/เรือนจำ
# 839471                ชลบุรี                  ทัณฑสถาน/เรือนจำ
# 839472                ชลบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 31                ชลบุรี               NaN
# 43                ชลบุรี           ศรีราชา
# 44                ชลบุรี               NaN
# 154               ชลบุรี             เมือง
# 222               ชลบุรี               NaN
# ...                  ...               ...
# 839468            ชลบุรี               NaN
# 839469            ชลบุรี               NaN
# 839470            ชลบุรี               NaN
# 839471            ชลบุรี               NaN
# 839472            ชลบุรี               NaN
#
# [44049 rows x 11 columns]

# %%
dataCN[['risk']].dropna().mode().iloc[0,0]
# Out:
# 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'

# %% [markdown]
# ## [PD] ต่อตาราง แกน Y

# %%
dataKKCN = pd.concat([dataKK,dataCN])
dataKKCN
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 181        182     18/3/2020     15/3/2020   ชาย  33.0   ปี    Thailand
# 463        464     22/3/2020     21/3/2020  หญิง  36.0   ปี    Thailand
# 1467      1468     30/3/2020     26/3/2020   ชาย  19.0   ปี    Thailand
# 1971      1972      3/4/2020     31/3/2020  หญิง  70.0   ปี    Thailand
# 2638      2639     15/4/2020     14/4/2020  หญิง  63.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 839468  839469     12/8/2021     11/8/2021   ชาย  29.0   ปี    Thailand
# 839469  839470     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839470  839471     12/8/2021     11/8/2021   ชาย  21.0   ปี    Thailand
# 839471  839472     12/8/2021     11/8/2021   ชาย  30.0   ปี    Thailand
# 839472  839473     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
#
#        province_of_isolation                                           risk  \
# 181                  ขอนแก่น                                        สนามมวย
# 463                  ขอนแก่น    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1467                 ขอนแก่น                  คนไทยเดินทางกลับจากต่างประเทศ
# 1971                 ขอนแก่น  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2638                 ขอนแก่น                  สัมผัสผู้เดินทางจากต่างประเทศ
# ...                      ...                                            ...
# 839468                ชลบุรี                               ทัณฑสถาน/เรือนจำ
# 839469                ชลบุรี                               ทัณฑสถาน/เรือนจำ
# 839470                ชลบุรี                               ทัณฑสถาน/เรือนจำ
# 839471                ชลบุรี                               ทัณฑสถาน/เรือนจำ
# 839472                ชลบุรี                               ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 181              ขอนแก่น             เมือง
# 463              ขอนแก่น             เมือง
# 1467             ขอนแก่น             เมือง
# 1971             ขอนแก่น             เมือง
# 2638             ขอนแก่น            น้ำพอง
# ...                  ...               ...
# 839468            ชลบุรี               NaN
# 839469            ชลบุรี               NaN
# 839470            ชลบุรี               NaN
# 839471            ชลบุรี               NaN
# 839472            ชลบุรี               NaN
#
# [49464 rows x 11 columns]

# %%
X = list(set(data_cases['province_of_onset']))
X
# Out:
# ['ปัตตานี',
#  'น่าน',
#  'หนองบััวลำภู',
#  'ราชบุรี',
#  'นครปบม',
#  'กาฬสินธิ์',
#  'นคปฐม',
#  '\xa0อุทัยธานี',
#  'นอกเขต',
#  'ประจวบคีรีขันธ์',
#  'ปทุุมธานี',
#  'เพชรบูรณ์',
#  'เมือง',
#  'ชลบุุรี',
#  'พม่า',
#  'ท้ายบ้าน',
#  'ปมุมธานี',
#  'สระแก้ว',
#  'อุตรดิตถ์',
#  'เมืองน่าน',
#  'นครพนม',
#  'ชัยนาท',
#  'ลพบุรี',
#  'มาเลเซีย',
#  'ปลายพระยา',
#  'บางกะปิ',
#  'สมถทรปราการ',
#  'พระนครศรีอยุธยา',
#  'สุพรรณบุรี',
#  'สมทรสาคร',
#  'กทม',
#  'กำแพงเพชร',
#  'บ้านหลวง',
#  'วังชิ้น',
#  'ยโสธร',
#  'แม่ฮ่องสอน',
#  'หนองคาย',
#  'ภูเพียง',
#  'ระยอง',
#  nan,
#  'สตูล',
#  'สมุทรปรากรร',
#  'ศรีษะเกษ',
#  'ลาดพร้าว',
#  'เชียงใหม่',
#  'ปราจีนบุรี',
#  'สมุทรสงคราม',
#  'ฉะเชิงเทรา',
#  'สุราษฎร์์ธานี',
#  'ชมพร',
#  'ลอง',
#  'ประจวบฯ',
#  'สองแคว',
#  'บุรีรัยม์',
#  'อุุดรธานี',
#  'ไม่ระบุ',
#  'ชลบุรี',
#  'แล้วป่วย',
#  'อำนาจเจริญ',
#  'เวียงสา',
#  'สุราษฏร์ธานี',
#  'ตาก',
#  'สุุราษฎร์ธานี',
#  'นครศร๊ะรรมราช',
#  'อยุธยา',
#  'สุมทรสาคร',
#  'เด่นชัย',
#  'สุวรรณภูมิ',
#  'กาฬสินธ์',
#  'เชียงราย',
#  '\xa0กาญจนบุรี',
#  'ชัยภูมิ',
#  'อุทัยธานี',
#  'กรุงเทพมหานคร',
#  'สมุทรปราการ',
#  'กัมพูชา',
#  'พะเยา',
#  'เลย',
#  'เรือ',
#  'มหาสาคาม',
#  'ปุทมธานี',
#  'เพชรบุรี',
#  'ศรีสะเกษ',
#  'เชีียงราย',
#  'กาฬสินธุ์',
#  'นาวัง',
#  'ขัยนาท',
#  'กระบี่',
#  '\xa0ชลบุรี',
#  'สกลนคร',
#  'สูงเม่น',
#  'สระบุรี',
#  'ยะลา',
#  'นครราชสีมา',
#  'อุุทัยธานี',
#  'สมุทราปราการ',
#  'พิษณุโลก',
#  'สมุทสาคร',
#  'นราธิวาส',
#  'บึงโขงหลง',
#  'สงขลา',
#  'อุบลราขธานี',
#  '\xa0สมุทรสาคร',
#  'ร้อยเอ็ด',
#  'มุกดาหาร',
#  'ปลวกแดง',
#  'ยานนาวา',
#  'สุรินทร์',
#  'สุทรปราการ',
#  'สุมุทรปราการ',
#  'สมุครปราการ',
#  'บุรีรัมย์\xa0',
#  'นครศรีธรรมราช',
#  'นนทบุรี',
#  'จันทบุรี',
#  'สถานที่ทำงาน',
#  'ระนอง',
#  'สมุทสงคราม',
#  'ลำลูกกา',
#  'เวียงจันทร์',
#  'ลำปาง',
#  'นครนาชสีมา',
#  'อุุดรธาน',
#  'เพชรบุูรณ์',
#  '\xa0ตราด',
#  'ชุมพร',
#  'นคนปฐม',
#  'นครนายก',
#  '\xa0สมุทรสงคราม',
#  'อํานาจเจริญ',
#  'สมุทรสาคร',
#  'ตราด',
#  'อยุุธยา',
#  'ลำพูน',
#  'สารภี',
#  'ธารโต',
#  'พัทลุง',
#  'ตรัง',
#  'สิงห์บุรี',
#  'สุราษฎร์ธานี',
#  'สมุทรปรากร',
#  'พิษณูโลก',
#  'ขอนแก่น',
#  'มหาสารคาม',
#  'ชุุมพร',
#  'สุโขทัย',
#  'พิจิตร',
#  'กาญจนบุรี',
#  'อุดรธานี',
#  'ปทุมธานี',
#  'อุดรธานีี',
#  'นครสวรรค์',
#  'ปทุมธานี.',
#  'ร้องกวาง',
#  'สะแก้ว',
#  'นครปฐม',
#  '\xa0นครปฐม',
#  'บึงกาฬ',
#  'ชลบุรี\t',
#  'หนองบัวลำภู',
#  'อ่างทอง',
#  'นตรปฐม',
#  'พังงา',
#  'สุมทรปราการ',
#  'สมุุทรปราการ',
#  'ปทุมธานีี',
#  'สงขลา\u200b',
#  'อุุตรดิตถ์',
#  'อยุทธยา',
#  'ภูเก็ต',
#  'ปัว',
#  'นาราธิวาส',
#  'หนองม่วงไข่',
#  'สอง',
#  'ขอนแก่่น',
#  'บุรีรัมย์',
#  'แพร่',
#  'สุมุทรสาคร',
#  'ปัตาตานี',
#  'อุบลราชธานี',
#  'สมุุทรสาคร']

# %%
dataCN = data_cases[data_cases['province_of_onset']==X[0]]

# %%
dataCN
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 163        164     17/3/2020    99/99/9999   ชาย  46.0   ปี    Thailand
# 165        166     17/3/2020    99/99/9999   ชาย  72.0   ปี    Thailand
# 213        214     19/3/2020    99/99/9999   ชาย  64.0   ปี    Thailand
# 215        216     19/3/2020    99/99/9999   ชาย  58.0   ปี    Thailand
# 216        217     19/3/2020    99/99/9999   ชาย  45.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 834535  834536     12/8/2021     11/8/2021   ชาย  77.0   ปี    Thailand
# 834536  834537     12/8/2021     11/8/2021   ชาย  77.0   ปี    Thailand
# 834537  834538     12/8/2021     11/8/2021  หญิง  21.0   ปี    Thailand
# 834538  834539     12/8/2021     11/8/2021   ชาย  13.0   ปี    Thailand
# 834539  834540     12/8/2021     11/8/2021   ชาย  29.0   ปี    Thailand
#
#        province_of_isolation                                         risk  \
# 163                  ปัตตานี                             พิธีกรรมทางศาสนา
# 165                  ปัตตานี                             พิธีกรรมทางศาสนา
# 213                  ปัตตานี                             พิธีกรรมทางศาสนา
# 215                  ปัตตานี                             พิธีกรรมทางศาสนา
# 216                  ปัตตานี                             พิธีกรรมทางศาสนา
# ...                      ...                                          ...
# 834535               ปัตตานี              บุคลากรด้านการแพทย์และสาธารณสุข
# 834536               ปัตตานี                        ปอดอักเสบ (Pneumonia)
# 834537               ปัตตานี              บุคลากรด้านการแพทย์และสาธารณสุข
# 834538               ปัตตานี  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 834539               ปัตตานี                             State Quarantine
#
#        province_of_onset district_of_onset
# 163              ปัตตานี           หนองจิก
# 165              ปัตตานี           โคกโพธ์
# 213              ปัตตานี           โคกโพธ์
# 215              ปัตตานี             ยะรัง
# 216              ปัตตานี             ยะรัง
# ...                  ...               ...
# 834535           ปัตตานี      เมืองปัตตานี
# 834536           ปัตตานี             ยะรัง
# 834537           ปัตตานี             ยะรัง
# 834538           ปัตตานี             กะพ้อ
# 834539           ปัตตานี        ทุ่งยางแดง
#
# [12160 rows x 11 columns]

# %%
prov_list = list()
for e_province in list(set(data_cases['province_of_onset']))[1:]:
    print(e_province)
    dataCN = data_cases[data_cases['province_of_onset']==e_province]
    print(dataCN[['risk']])
    dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
    prov_list.append(dataCN) ##
dataALL = pd.concat(prov_list)
# Out:
# น่าน
#                                                risk
# 8478                           อยู่ระหว่างการสอบสวน
# 30342                          Cluster ผับ Thonglor
# 35343   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 40631   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 40632                                   สถานบันเทิง
# ...                                             ...
# 796077                                        อื่นๆ
# 796078                                        อื่นๆ
# 806863                                        อื่นๆ
# 821120                                        อื่นๆ
# 837997                                        อื่นๆ
#
# [1600 rows x 1 columns]
# หนองบััวลำภู
#                                                risk
# 48694   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 349473  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 377371                                        อื่นๆ
# ราชบุรี
#                                                risk
# 581                           ปอดอักเสบ (Pneumonia)
# 719                                     สถานบันเทิง
# 753                   คนไทยเดินทางกลับจากต่างประเทศ
# 873                คนต่างชาติเดินทางมาจากต่างประเทศ
# 875     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                                             ...
# 824244                                        อื่นๆ
# 824245  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 824246  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 824247  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 839184                                        อื่นๆ
#
# [8208 rows x 1 columns]
# นครปบม
#          risk
# 727065  อื่นๆ
# กาฬสินธิ์
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
#                                                risk
# 695287  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 709461                                        อื่นๆ
# นคปฐม
#          risk
# 330099  อื่นๆ
# 330100  อื่นๆ
#  อุทัยธานี
#                         risk
# 763594  อยู่ระหว่างการสอบสวน
# นอกเขต
#          risk
# 597815  อื่นๆ
# ประจวบคีรีขันธ์
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
#                                                      risk
# 7                        คนต่างชาติเดินทางมาจากต่างประเทศ
# 22      อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 375                         คนไทยเดินทางกลับจากต่างประเทศ
# 376                         คนไทยเดินทางกลับจากต่างประเทศ
# 387                      คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                                                   ...
# 824327        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 824328        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 836418                                         ระบุไม่ได้
# 836854                                         ระบุไม่ได้
# 838464   การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน
#
# [4350 rows x 1 columns]
# ปทุุมธานี
#          risk
# 704783  อื่นๆ
# เพชรบูรณ์
#                                                      risk
# 146                      คนต่างชาติเดินทางมาจากต่างประเทศ
# 437     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 487     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 5729                                    Cluster สมุทรสาคร
# 30319                                Cluster ผับ Thonglor
# ...                                                   ...
# 834970                                         ระบุไม่ได้
# 836526                                         ระบุไม่ได้
# 836724                                         ระบุไม่ได้
# 838088                                         ระบุไม่ได้
# 838930        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [3358 rows x 1 columns]
# เมือง
#                                                risk
# 264858  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 403555                                        อื่นๆ
# 537495  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ชลบุุรี
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
#          risk
# 686636  อื่นๆ
# 686637  อื่นๆ
# พม่า
#                                               risk
# 5838  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# ท้ายบ้าน
#          risk
# 704885  อื่นๆ
# ปมุมธานี
#                                                risk
# 654290  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 725987                                        อื่นๆ
# สระแก้ว
#                                                      risk
# 452                         คนไทยเดินทางกลับจากต่างประเทศ
# 462           สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 738                         คนไทยเดินทางกลับจากต่างประเทศ
# 742                         คนไทยเดินทางกลับจากต่างประเทศ
# 792                         คนไทยเดินทางกลับจากต่างประเทศ
# ...                                                   ...
# 824418  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 824419  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 824420  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 828816                                              อื่นๆ
# 828817                                              อื่นๆ
#
# [4285 rows x 1 columns]
# อุตรดิตถ์
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
#                                                     risk
# 1462                       คนไทยเดินทางกลับจากต่างประเทศ
# 1542         สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1543         สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 5313                                   Cluster สมุทรสาคร
# 5777                                   Cluster สมุทรสาคร
# ...                                                  ...
# 817415                                             อื่นๆ
# 817416                                             อื่นๆ
# 817417                                             อื่นๆ
# 817418                                             อื่นๆ
# 839021  การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน
#
# [2167 rows x 1 columns]
# เมืองน่าน
#                                                risk
# 392043  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 392044  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 392045  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 392046  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 392048  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 392049  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 392056  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 392058  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 392063  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# นครพนม
#                                                      risk
# 1363    อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 2555          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11929                                   Cluster สมุทรสาคร
# 12595         สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 30904         สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                                                   ...
# 835722                                         ระบุไม่ได้
# 836550                                         ระบุไม่ได้
# 836803                                         ระบุไม่ได้
# 837196                                         ระบุไม่ได้
# 838266                                         ระบุไม่ได้
#
# [2356 rows x 1 columns]
# ชัยนาท
#                                                risk
# 5775                              Cluster สมุทรสาคร
# 5916                              Cluster สมุทรสาคร
# 5918                              Cluster สมุทรสาคร
# 5919                              Cluster สมุทรสาคร
# 5920                              Cluster สมุทรสาคร
# ...                                             ...
# 818128                                        อื่นๆ
# 818129  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 818130  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 818131                                        อื่นๆ
# 820300  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [1456 rows x 1 columns]
# ลพบุรี
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
#                                                      risk
# 331                                               สนามมวย
# 657     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 2253                      บุคลากรด้านการแพทย์และสาธารณสุข
# 6185                                    Cluster สมุทรสาคร
# 9030                               Cluster บ่อนไก่อ่างทอง
# ...                                                   ...
# 819792        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 819844        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 834944                                         ระบุไม่ได้
# 835081                                         ระบุไม่ได้
# 836521                                         ระบุไม่ได้
#
# [7082 rows x 1 columns]
# มาเลเซีย
#                    risk
# 89853  State Quarantine
# 89855  State Quarantine
# ปลายพระยา
#                                                risk
# 378194  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# บางกะปิ
#          risk
# 411534  อื่นๆ
# สมถทรปราการ
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
#                         risk
# 640010  อยู่ระหว่างการสอบสวน
# พระนครศรีอยุธยา
#                                                      risk
# 2013                        คนไทยเดินทางกลับจากต่างประเทศ
# 2075          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2404    อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 2820          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2825    อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# ...                                                   ...
# 839715                                   ทัณฑสถาน/เรือนจำ
# 839716                                   ทัณฑสถาน/เรือนจำ
# 839717                                   ทัณฑสถาน/เรือนจำ
# 839718                                   ทัณฑสถาน/เรือนจำ
# 839719                                   ทัณฑสถาน/เรือนจำ
#
# [14105 rows x 1 columns]
# สุพรรณบุรี
#                                                      risk
# 50            สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1481    อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 1986          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1987          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2222          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                                                   ...
# 823370        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 823371                                              อื่นๆ
# 835063                                         ระบุไม่ได้
# 836392                                         ระบุไม่ได้
# 837556        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [7030 rows x 1 columns]
# สมทรสาคร
#          risk
# 686595  อื่นๆ
# กทม
#                                                risk
# 697420  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 704259                                        อื่นๆ
# 704803                                        อื่นๆ
# 707350  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 707391                                        อื่นๆ
# 707407                                        อื่นๆ
# 707521                                        อื่นๆ
# 707522                                        อื่นๆ
# 707524                                        อื่นๆ
# 707525                                        อื่นๆ
# 707528                                        อื่นๆ
# 707529                                        อื่นๆ
# 707530                                        อื่นๆ
# 707531                                        อื่นๆ
# 707538                                        อื่นๆ
# 707539                                        อื่นๆ
# 707540                                        อื่นๆ
# 707562                                        อื่นๆ
# 707570  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 707582                                        อื่นๆ
# 707612                                        อื่นๆ
# กำแพงเพชร
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
#                                                     risk
# 5757                                   Cluster สมุทรสาคร
# 31649        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 31657        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 31716                                        สถานบันเทิง
# 31910        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                                                  ...
# 817897       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 817898       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 817899  การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน
# 835492                                             อื่นๆ
# 836528                                        ระบุไม่ได้
#
# [3958 rows x 1 columns]
# บ้านหลวง
#                                                risk
# 392050  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 392054  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 392055  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 392057  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# วังชิ้น
#          risk
# 403570  อื่นๆ
# ยโสธร
#                                                risk
# 620                   คนไทยเดินทางกลับจากต่างประเทศ
# 2778    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 27674                             Cluster สมุทรสาคร
# 29963                          Cluster ผับ Thonglor
# 31033                          Cluster ผับ Thonglor
# ...                                             ...
# 836393                                   ระบุไม่ได้
# 836487                                   ระบุไม่ได้
# 836967                                   ระบุไม่ได้
# 837198                                   ระบุไม่ได้
# 839093                                        อื่นๆ
#
# [395 rows x 1 columns]
# แม่ฮ่องสอน
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
#                                                risk
# 1089                  คนไทยเดินทางกลับจากต่างประเทศ
# 1155    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1156    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1157    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1461                  คนไทยเดินทางกลับจากต่างประเทศ
# ...                                             ...
# 796153                                        อื่นๆ
# 796154                                        อื่นๆ
# 796155                                        อื่นๆ
# 796156                                        อื่นๆ
# 796157                                        อื่นๆ
#
# [123 rows x 1 columns]
# หนองคาย
#                                                risk
# 1052                                    สถานบันเทิง
# 1886    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10835   สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 30903                                   สถานบันเทิง
# 31044                          Cluster ผับ Thonglor
# ...                                             ...
# 830306                         อยู่ระหว่างการสอบสวน
# 830307                         อยู่ระหว่างการสอบสวน
# 830308                         อยู่ระหว่างการสอบสวน
# 830309                         อยู่ระหว่างการสอบสวน
# 830310                         อยู่ระหว่างการสอบสวน
#
# [1268 rows x 1 columns]
# ภูเพียง
#                                                risk
# 392041  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 392042  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 392060  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 392061  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ระยอง
#                                                     risk
# 265          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 371          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 477                        คนไทยเดินทางกลับจากต่างประเทศ
# 700          สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1100         สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                                                  ...
# 832532     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 832590     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 832666     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 832720     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 838724  การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน
#
# [12041 rows x 1 columns]
# nan
# Empty DataFrame
# Columns: [risk]
# Index: []
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-108-eac569d56cfa>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-108-eac569d56cfa> in <cell line: 2>()
#       4     dataCN = data_cases[data_cases['province_of_onset']==e_province]
#       5     print(dataCN[['risk']])
# ----> 6     dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
#       7     prov_list.append(dataCN) ##
#       8 dataALL = pd.concat(prov_list)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1064             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1065             if self._is_scalar_access(key):
# -> 1066                 return self.obj._get_value(*key, takeable=self._takeable)
#    1067             return self._getitem_tuple(key)
#    1068         else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    3913         if takeable:
#    3914             series = self._ixs(col, axis=1)
# -> 3915             return series._values[index]
#    3916
#    3917         series = self._get_item_cache(col)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
prov_list = list()
for e_province in list(set(data_cases['province_of_onset']))[1:]:
    print(e_province)
    dataCN = data_cases[data_cases['province_of_onset']==e_province]
    if all(dataCN[['risk']].isna()):
        dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
    else:
        dataCN[['risk']] = dataCN[['risk']].fillna(dataCN[['risk']].dropna().mode().iloc[0,0])
    prov_list.append(dataCN) ##
dataALL = pd.concat(prov_list)
# Out:
# น่าน
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# หนองบััวลำภู
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ราชบุรี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# นครปบม
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# กาฬสินธิ์
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# นคปฐม
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
#  อุทัยธานี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# นอกเขต
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ประจวบคีรีขันธ์
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ปทุุมธานี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# เพชรบูรณ์
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# เมือง
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ชลบุุรี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# พม่า
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ท้ายบ้าน
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ปมุมธานี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สระแก้ว
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# อุตรดิตถ์
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# เมืองน่าน
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# นครพนม
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ชัยนาท
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ลพบุรี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# มาเลเซีย
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ปลายพระยา
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# บางกะปิ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สมถทรปราการ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# พระนครศรีอยุธยา
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สุพรรณบุรี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สมทรสาคร
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# กทม
# กำแพงเพชร
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# บ้านหลวง
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# วังชิ้น
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ยโสธร
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# แม่ฮ่องสอน
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# หนองคาย
# ภูเพียง
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ระยอง
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# nan
# สตูล
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สมุทรปรากรร
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ศรีษะเกษ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ลาดพร้าว
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# เชียงใหม่
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ปราจีนบุรี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สมุทรสงคราม
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ฉะเชิงเทรา
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สุราษฎร์์ธานี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ชมพร
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ลอง
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ประจวบฯ
# สองแคว
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# บุรีรัยม์
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# อุุดรธานี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ไม่ระบุ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ชลบุรี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# แล้วป่วย
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# อำนาจเจริญ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# เวียงสา
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สุราษฏร์ธานี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ตาก
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สุุราษฎร์ธานี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# นครศร๊ะรรมราช
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# อยุธยา
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สุมทรสาคร
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# เด่นชัย
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สุวรรณภูมิ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# กาฬสินธ์
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# เชียงราย
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
#  กาญจนบุรี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ชัยภูมิ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# อุทัยธานี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# กรุงเทพมหานคร
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สมุทรปราการ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# กัมพูชา
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# พะเยา
# เลย
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# เรือ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# มหาสาคาม
# ปุทมธานี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# เพชรบุรี
# ศรีสะเกษ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# เชีียงราย
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# กาฬสินธุ์
# นาวัง
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ขัยนาท
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# กระบี่
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
#  ชลบุรี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สกลนคร
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สูงเม่น
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สระบุรี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ยะลา
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# นครราชสีมา
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# อุุทัยธานี
# สมุทราปราการ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# พิษณุโลก
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สมุทสาคร
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# นราธิวาส
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# บึงโขงหลง
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สงขลา
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# อุบลราขธานี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
#  สมุทรสาคร
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ร้อยเอ็ด
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# มุกดาหาร
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ปลวกแดง
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ยานนาวา
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สุรินทร์
# สุทรปราการ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สุมุทรปราการ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สมุครปราการ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# บุรีรัมย์
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# นครศรีธรรมราช
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# นนทบุรี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# จันทบุรี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ชุุมพร
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สุโขทัย
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# พิจิตร
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# กาญจนบุรี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# อุดรธานี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ปทุมธานี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# อุดรธานีี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# นครสวรรค์
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ปทุมธานี.
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ร้องกวาง
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สะแก้ว
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# นครปฐม
#  นครปฐม
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# บึงกาฬ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ชลบุรี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# หนองบัวลำภู
# อ่างทอง
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# นตรปฐม
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# พังงา
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สุมทรปราการ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สมุุทรปราการ
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ปทุมธานีี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สงขลา​
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# อุุตรดิตถ์
# อยุทธยา
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ภูเก็ต
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ปัว
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# นาราธิวาส
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# หนองม่วงไข่
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สอง
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ขอนแก่่น
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# บุรีรัมย์
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# แพร่
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สุมุทรสาคร
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# ปัตาตานี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# อุบลราชธานี
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])
# สมุุทรสาคร
# <ipython-input-91-9ae0a19cef65>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCN[['risk']] = dataCN[['risk']].fillna(data_cases[['risk']].dropna().mode().iloc[0,0])

# %%
dataALL
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 8478      8479      5/1/2021      4/1/2021  หญิง  23.0   ปี        Laos
# 30342    30343      9/4/2021      8/4/2021   ชาย  41.0   ปี    Thailand
# 35343    35344     14/4/2021     13/4/2021  หญิง  35.0   ปี    Thailand
# 40631    40632     18/4/2021     17/4/2021   ชาย  28.0   ปี    Thailand
# 40632    40633     18/4/2021     17/4/2021  หญิง  35.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 839518  839519     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839519  839520     12/8/2021     11/8/2021   ชาย  44.0   ปี    Thailand
# 839520  839521     12/8/2021     11/8/2021   ชาย  39.0   ปี    Thailand
# 839521  839522     12/8/2021     11/8/2021   ชาย  25.0   ปี    Thailand
# 726115  726116      7/8/2021      6/8/2021   ชาย  45.0   ปี    Thailand
#
#        province_of_isolation                                         risk  \
# 8478                    น่าน                         อยู่ระหว่างการสอบสวน
# 30342                   น่าน                         Cluster ผับ Thonglor
# 35343          กรุงเทพมหานคร  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 40631                   น่าน  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 40632                   น่าน                                  สถานบันเทิง
# ...                      ...                                          ...
# 839518           อุบลราชธานี                             ทัณฑสถาน/เรือนจำ
# 839519           อุบลราชธานี                             ทัณฑสถาน/เรือนจำ
# 839520           อุบลราชธานี                             ทัณฑสถาน/เรือนจำ
# 839521           อุบลราชธานี                             ทัณฑสถาน/เรือนจำ
# 726115               สระแก้ว  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#        province_of_onset district_of_onset
# 8478                น่าน           นาหมื่น
# 30342               น่าน           เวียงสา
# 35343               น่าน          ทุ่งช้าง
# 40631               น่าน             เมือง
# 40632               น่าน               ปัว
# ...                  ...               ...
# 839518       อุบลราชธานี               NaN
# 839519       อุบลราชธานี               NaN
# 839520       อุบลราชธานี               NaN
# 839521       อุบลราชธานี               NaN
# 726115        สมุุทรสาคร             เมือง
#
# [728577 rows x 11 columns]

# %%
datamissingonset = data_cases[pd.isna(data_cases['province_of_onset'])]
datamissingonset
# Out:
#            No. announce_date Notified date   sex        age Unit nationality  \
# 415        416     22/3/2020     22/3/2020   ชาย  29.000000   ปี    Thailand
# 530        531     22/3/2020     20/3/2020   ชาย  37.000000   ปี    Thailand
# 556        557     22/3/2020     21/3/2020  หญิง   6.000000   ปี    Thailand
# 577        578     22/3/2020     20/3/2020   ชาย  35.700109   ปี    Thailand
# 589        590     22/3/2020     21/3/2020   ชาย  35.700109   ปี    Thailand
# ...        ...           ...           ...   ...        ...  ...         ...
# 838196  838197     12/8/2021     11/8/2021  หญิง  36.000000   ปี        ไทย?
# 838371  838372     12/8/2021     11/8/2021   ชาย  28.000000   ปี   Cambodian
# 838395  838396     12/8/2021     11/8/2021   ชาย  45.000000   ปี   Cambodian
# 839144  839145     12/8/2021     11/8/2021   ชาย  76.000000   ปี    Thailand
# 839304  839305     12/8/2021     11/8/2021  หญิง  35.700109   ปี        ไทย?
#
#        province_of_isolation                                         risk  \
# 415            กรุงเทพมหานคร                                      สนามมวย
# 530            กรุงเทพมหานคร  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 556            กรุงเทพมหานคร                                      สนามมวย
# 577            กรุงเทพมหานคร                                      สนามมวย
# 589            กรุงเทพมหานคร                         อยู่ระหว่างการสอบสวน
# ...                      ...                                          ...
# 838196         กรุงเทพมหานคร                                   ระบุไม่ได้
# 838371         กรุงเทพมหานคร                                        อื่นๆ
# 838395         กรุงเทพมหานคร                                   ระบุไม่ได้
# 839144         กรุงเทพมหานคร                                        อื่นๆ
# 839304         กรุงเทพมหานคร                                   ระบุไม่ได้
#
#        province_of_onset district_of_onset
# 415                  NaN               NaN
# 530                  NaN               NaN
# 556                  NaN               NaN
# 577                  NaN               NaN
# 589                  NaN               NaN
# ...                  ...               ...
# 838196               NaN               NaN
# 838371               NaN               NaN
# 838395               NaN               NaN
# 839144               NaN               NaN
# 839304               NaN               NaN
#
# [99034 rows x 11 columns]

# %%
datamissingonset[['risk']] = datamissingonset[['risk']].fillna(datamissingonset[['risk']].dropna().mode().iloc[0,0])
# Out:
# <ipython-input-111-38d97297ccf5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datamissingonset[['risk']] = datamissingonset[['risk']].fillna(datamissingonset[['risk']].dropna().mode().iloc[0,0])

# %%
dataALL = pd.concat([dataALL,datamissingonset])

# %%
dataALL
# Out:
#            No. announce_date Notified date   sex        age Unit nationality  \
# 8478      8479      5/1/2021      4/1/2021  หญิง  23.000000   ปี        Laos
# 30342    30343      9/4/2021      8/4/2021   ชาย  41.000000   ปี    Thailand
# 35343    35344     14/4/2021     13/4/2021  หญิง  35.000000   ปี    Thailand
# 40631    40632     18/4/2021     17/4/2021   ชาย  28.000000   ปี    Thailand
# 40632    40633     18/4/2021     17/4/2021  หญิง  35.000000   ปี    Thailand
# ...        ...           ...           ...   ...        ...  ...         ...
# 838196  838197     12/8/2021     11/8/2021  หญิง  36.000000   ปี        ไทย?
# 838371  838372     12/8/2021     11/8/2021   ชาย  28.000000   ปี   Cambodian
# 838395  838396     12/8/2021     11/8/2021   ชาย  45.000000   ปี   Cambodian
# 839144  839145     12/8/2021     11/8/2021   ชาย  76.000000   ปี    Thailand
# 839304  839305     12/8/2021     11/8/2021  หญิง  35.700109   ปี        ไทย?
#
#        province_of_isolation                                         risk  \
# 8478                    น่าน                         อยู่ระหว่างการสอบสวน
# 30342                   น่าน                         Cluster ผับ Thonglor
# 35343          กรุงเทพมหานคร  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 40631                   น่าน  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 40632                   น่าน                                  สถานบันเทิง
# ...                      ...                                          ...
# 838196         กรุงเทพมหานคร                                   ระบุไม่ได้
# 838371         กรุงเทพมหานคร                                        อื่นๆ
# 838395         กรุงเทพมหานคร                                   ระบุไม่ได้
# 839144         กรุงเทพมหานคร                                        อื่นๆ
# 839304         กรุงเทพมหานคร                                   ระบุไม่ได้
#
#        province_of_onset district_of_onset
# 8478                น่าน           นาหมื่น
# 30342               น่าน           เวียงสา
# 35343               น่าน          ทุ่งช้าง
# 40631               น่าน             เมือง
# 40632               น่าน               ปัว
# ...                  ...               ...
# 838196               NaN               NaN
# 838371               NaN               NaN
# 838395               NaN               NaN
# 839144               NaN               NaN
# 839304               NaN               NaN
#
# [827611 rows x 11 columns]

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 2            3     22/1/2020    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020    99/99/9999   ชาย  68.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [839771 rows x 11 columns]

# %%
dataALL.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
dataALL = dataALL.sort_values(by='No.')
dataALL
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 2            3     22/1/2020    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020    99/99/9999   ชาย  68.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [827611 rows x 11 columns]

# %%
dataALL.keys()
# Out:
# Index(['No.', 'announce_date', 'Notified date', 'sex', 'age', 'Unit',
#        'nationality', 'province_of_isolation', 'risk', 'province_of_onset',
#        'district_of_onset'],
#       dtype='object')

# %% [markdown]
# ## การทำงานกับ Datetime-Timestamp
#
# https://towardsdatascience.com/working-with-datetime-in-pandas-dataframe-663f7af6c587
#
# https://realpython.com/python-datetime/

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020    99/99/9999  หญิง  61.0   ปี       China
# 1            2     17/1/2020    99/99/9999  หญิง  74.0   ปี       China
# 2            3     22/1/2020    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020    99/99/9999   ชาย  68.0   ปี       China
# 4            5     24/1/2020    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [839771 rows x 11 columns]

# %%
data_cases.sort_values(by=['announce_date']).iloc[270:290]
# Out:
#        No. announce_date Notified date   sex        age Unit     nationality  \
# 7073  7074      1/1/2021    31/12/2020  หญิง  35.700109   ปี        Thailand
# 7072  7073      1/1/2021    31/12/2020  หญิง  35.700109   ปี           Burma
# 7071  7072      1/1/2021    31/12/2020  หญิง  35.700109   ปี        Thailand
# 7065  7066      1/1/2021    31/12/2020   ชาย  35.700109   ปี        Thailand
# 7069  7070      1/1/2021    31/12/2020   ชาย  35.700109   ปี        Thailand
# 7068  7069      1/1/2021    31/12/2020   ชาย  35.700109   ปี        Thailand
# 7067  7068      1/1/2021    31/12/2020  หญิง  35.700109   ปี        Thailand
# 7093  7094      1/1/2021    31/12/2020   ชาย  35.700109   ปี        Thailand
# 7066  7067      1/1/2021    31/12/2020  หญิง  35.700109   ปี        Thailand
# 3567  3568     1/10/2020     30/9/2020   ชาย  41.000000   ปี           India
# 3566  3567     1/10/2020     30/9/2020   ชาย  48.000000   ปี        Thailand
# 3569  3570     1/10/2020     30/9/2020  หญิง  28.000000   ปี          Brazil
# 3568  3569     1/10/2020     30/9/2020   ชาย  28.000000   ปี          Brazil
# 3565  3566     1/10/2020     30/9/2020   ชาย  26.000000   ปี     Philippines
# 3784  3785     1/11/2020    31/10/2020   ชาย  41.000000   ปี          Russia
# 3781  3782     1/11/2020    31/10/2020   ชาย  28.000000   ปี  United Kingdom
# 3782  3783     1/11/2020    31/10/2020   ชาย  65.000000   ปี  United Kingdom
# 3783  3784     1/11/2020    31/10/2020  หญิง  27.000000   ปี        Thailand
# 4007  4008     1/12/2020    30/11/2020  หญิง  63.000000   ปี        Thailand
# 3999  4000     1/12/2020    30/11/2020  หญิง  30.000000   ปี        Pakistan
#
#      province_of_isolation                                          risk  \
# 7073                ชลบุรี                          อยู่ระหว่างการสอบสวน
# 7072                ชลบุรี                          อยู่ระหว่างการสอบสวน
# 7071                ชลบุรี                          อยู่ระหว่างการสอบสวน
# 7065                ชลบุรี                          อยู่ระหว่างการสอบสวน
# 7069                ชลบุรี                          อยู่ระหว่างการสอบสวน
# 7068                ชลบุรี                          อยู่ระหว่างการสอบสวน
# 7067                ชลบุรี                          อยู่ระหว่างการสอบสวน
# 7093                 ระยอง                                 Cluster ระยอง
# 7066                ชลบุรี                          อยู่ระหว่างการสอบสวน
# 3567         กรุงเทพมหานคร  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 3566                ชลบุรี                              State Quarantine
# 3569         กรุงเทพมหานคร  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 3568         กรุงเทพมหานคร  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 3565         กรุงเทพมหานคร  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 3784         กรุงเทพมหานคร  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 3781         กรุงเทพมหานคร  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 3782               นนทบุรี  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 3783         กรุงเทพมหานคร                              State Quarantine
# 4007         กรุงเทพมหานคร  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# 3999           สมุทรปราการ  ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
#
#      province_of_onset district_of_onset
# 7073               NaN               NaN
# 7072               NaN               NaN
# 7071               NaN               NaN
# 7065               NaN               NaN
# 7069               NaN               NaN
# 7068               NaN               NaN
# 7067               NaN               NaN
# 7093               NaN               NaN
# 7066               NaN               NaN
# 3567     กรุงเทพมหานคร             บางนา
# 3566            ชลบุรี          บางละมุง
# 3569          ปทุมธานี          คลองหลวง
# 3568          ปทุมธานี          คลองหลวง
# 3565     กรุงเทพมหานคร            บางรัก
# 3784     กรุงเทพมหานคร            บางรัก
# 3781     กรุงเทพมหานคร           ปทุมวัน
# 3782           นนทบุรี          ปากเกร็ด
# 3783     กรุงเทพมหานคร            ดินแดง
# 4007     กรุงเทพมหานคร           สุรวงศ์
# 3999       สมุทรปราการ            บางบ่อ

# %%
from datetime import datetime

# %%
data_cases.iloc[0,1]
# Out:
# '12/1/2020'

# %%
t = pd.to_datetime(data_cases.iloc[0,1])
t
# Out:
# Timestamp('2020-12-01 00:00:00')

# %%
t = pd.to_datetime(data_cases.iloc[0,1],dayfirst=True)
t
# Out:
# Timestamp('2020-01-12 00:00:00')

# %%
data_cases['announce_date']=pd.to_datetime(data_cases['announce_date'])
# Out:
# <ipython-input-124-86b04c1e170e>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data_cases['announce_date']=pd.to_datetime(data_cases['announce_date'])

# %%
data_cases
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1    2020-12-01    99/99/9999  หญิง  61.0   ปี       China
# 1            2    2020-01-17    99/99/9999  หญิง  74.0   ปี       China
# 2            3    2020-01-22    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4    2020-01-22    99/99/9999   ชาย  68.0   ปี       China
# 4            5    2020-01-24    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767    2021-12-08     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768    2021-12-08     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769    2021-12-08     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770    2021-12-08     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771    2021-12-08     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [839771 rows x 11 columns]

# %%
dataALL['announce_date']=pd.to_datetime(dataALL['announce_date'],dayfirst=True)

# %%
dataALL
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1    2020-01-12    99/99/9999  หญิง  61.0   ปี       China
# 1            2    2020-01-17    99/99/9999  หญิง  74.0   ปี       China
# 2            3    2020-01-22    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4    2020-01-22    99/99/9999   ชาย  68.0   ปี       China
# 4            5    2020-01-24    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767    2021-08-12     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768    2021-08-12     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769    2021-08-12     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770    2021-08-12     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771    2021-08-12     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [827611 rows x 11 columns]

# %%
dataALL[dataALL['announce_date']==datetime(day=13,month=4,year=2020)]
# Out:
#        No. announce_date Notified date   sex        age Unit  nationality  \
# 2552  2553    2020-04-13     12/4/2020   ชาย  20.000000   ปี     Thailand
# 2553  2554    2020-04-13     12/4/2020   ชาย  24.000000   ปี     Thailand
# 2554  2555    2020-04-13     12/4/2020   ชาย  58.000000   ปี     Thailand
# 2555  2556    2020-04-13     12/4/2020  หญิง  34.000000   ปี     Thailand
# 2556  2557    2020-04-13     12/4/2020  หญิง  38.000000   ปี     Thailand
# 2557  2558    2020-04-13     12/4/2020   ชาย  31.000000   ปี     Thailand
# 2558  2559    2020-04-13     12/4/2020  หญิง  59.000000   ปี     Thailand
# 2559  2560    2020-04-13     12/4/2020   ชาย  70.000000   ปี     Thailand
# 2560  2561    2020-04-13     12/4/2020  หญิง  40.000000   ปี     Thailand
# 2561  2562    2020-04-13     12/4/2020  หญิง  50.000000   ปี     Thailand
# 2562  2563    2020-04-13     12/4/2020  หญิง  49.000000   ปี     Thailand
# 2563  2564    2020-04-13     12/4/2020  หญิง  31.000000   ปี     Thailand
# 2564  2565    2020-04-13     12/4/2020  หญิง   9.000000   ปี  Philippines
# 2565  2566    2020-04-13     12/4/2020  หญิง  35.700109   ปี     Thailand
# 2566  2567    2020-04-13     12/4/2020  หญิง  35.700109   ปี     Thailand
# 2567  2568    2020-04-13     12/4/2020   ชาย  35.700109   ปี     Thailand
# 2568  2569    2020-04-13     12/4/2020  หญิง  57.000000   ปี     Thailand
# 2569  2570    2020-04-13     12/4/2020   ชาย  58.000000   ปี     Thailand
# 2570  2571    2020-04-13     12/4/2020  หญิง  28.000000   ปี     Thailand
# 2571  2572    2020-04-13     12/4/2020   ชาย  57.000000   ปี     Thailand
# 2572  2573    2020-04-13     12/4/2020  หญิง  30.000000   ปี     Thailand
# 2573  2574    2020-04-13     12/4/2020   ชาย  38.000000   ปี     Thailand
# 2574  2575    2020-04-13     12/4/2020   ชาย  37.000000   ปี     Thailand
# 2575  2576    2020-04-13     12/4/2020  หญิง  33.000000   ปี     Thailand
# 2576  2577    2020-04-13     12/4/2020  หญิง  63.000000   ปี     Thailand
# 2577  2578    2020-04-13     12/4/2020   ชาย  41.000000   ปี     Thailand
# 2578  2579    2020-04-13     12/4/2020   ชาย  34.000000   ปี     Thailand
# 2579  2580    2020-04-13     12/4/2020   ชาย  23.000000   ปี     Thailand
#
#      province_of_isolation                                               risk  \
# 2552                ภูเก็ต        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2553                ภูเก็ต        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2554                  ยะลา        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2555                นครพนม        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2556         กรุงเทพมหานคร        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2557         กรุงเทพมหานคร        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2558                ภูเก็ต        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2559                ภูเก็ต        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2560                ภูเก็ต        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2561                ภูเก็ต        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2562         กรุงเทพมหานคร        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2563         กรุงเทพมหานคร        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2564         กรุงเทพมหานคร        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2565         กรุงเทพมหานคร        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2566         กรุงเทพมหานคร        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2567         กรุงเทพมหานคร        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2568         กรุงเทพมหานคร        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2569               นนทบุรี        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2570         กรุงเทพมหานคร                      คนไทยเดินทางกลับจากต่างประเทศ
# 2571                   เลย      ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2572                ชลบุรี  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 2573                ชลบุรี  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 2574         กรุงเทพมหานคร                    บุคลากรด้านการแพทย์และสาธารณสุข
# 2575         กรุงเทพมหานคร                    บุคลากรด้านการแพทย์และสาธารณสุข
# 2576                 ชุมพร        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2577                  สตูล                                   State Quarantine
# 2578                  สตูล                                   State Quarantine
# 2579                  ยะลา                                   State Quarantine
#
#      province_of_onset district_of_onset
# 2552            ภูเก็ต              ถลาง
# 2553            ภูเก็ต              ถลาง
# 2554              ยะลา             ธารโต
# 2555            นครพนม         ศรีสงคราม
# 2556     กรุงเทพมหานคร           ยานนาวา
# 2557     กรุงเทพมหานคร             วัฒนา
# 2558            ภูเก็ต              ถลาง
# 2559            ภูเก็ต              ถลาง
# 2560            ภูเก็ต              ถลาง
# 2561            ภูเก็ต              ถลาง
# 2562     กรุงเทพมหานคร               NaN
# 2563          ปทุมธานี            รังสิต
# 2564     กรุงเทพมหานคร               NaN
# 2565     กรุงเทพมหานคร               NaN
# 2566     กรุงเทพมหานคร               NaN
# 2567     กรุงเทพมหานคร               NaN
# 2568     กรุงเทพมหานคร           มีนบุรี
# 2569     กรุงเทพมหานคร               NaN
# 2570           นนทบุรี             เมือง
# 2571               เลย             เมือง
# 2572            ชลบุรี               NaN
# 2573            ชลบุรี               NaN
# 2574     กรุงเทพมหานคร           บางกะปิ
# 2575          ศรีสะเกษ          เมืองใต้
# 2576             ชุมพร             เมือง
# 2577              สตูล            ควนโดน
# 2578              สตูล            ควนโดน
# 2579              ยะลา             สะเตง

# %%
dataALL[(dataALL['announce_date']>=datetime(day=13,month=4,year=2020)) & (dataALL['announce_date']<=datetime(day=15,month=4,year=2020))]
# Out:
#        No. announce_date Notified date   sex   age Unit nationality  \
# 2552  2553    2020-04-13     12/4/2020   ชาย  20.0   ปี    Thailand
# 2553  2554    2020-04-13     12/4/2020   ชาย  24.0   ปี    Thailand
# 2554  2555    2020-04-13     12/4/2020   ชาย  58.0   ปี    Thailand
# 2555  2556    2020-04-13     12/4/2020  หญิง  34.0   ปี    Thailand
# 2556  2557    2020-04-13     12/4/2020  หญิง  38.0   ปี    Thailand
# ...    ...           ...           ...   ...   ...  ...         ...
# 2639  2640    2020-04-15     14/4/2020   ชาย  72.0   ปี    Thailand
# 2640  2641    2020-04-15     14/4/2020  หญิง  34.0   ปี    Thailand
# 2641  2642    2020-04-15     14/4/2020  หญิง  53.0   ปี    Thailand
# 2642  2643    2020-04-15     14/4/2020  หญิง  43.0   ปี       Burma
# 2643  2644    2020-04-15     14/4/2020   ชาย  30.0   ปี    Thailand
#
#      province_of_isolation                                         risk  \
# 2552                ภูเก็ต  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2553                ภูเก็ต  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2554                  ยะลา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2555                นครพนม  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2556         กรุงเทพมหานคร  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                    ...                                          ...
# 2639              นราธิวาส                        ปอดอักเสบ (Pneumonia)
# 2640         กรุงเทพมหานคร              บุคลากรด้านการแพทย์และสาธารณสุข
# 2641         กรุงเทพมหานคร  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2642         กรุงเทพมหานคร                                   ระบุไม่ได้
# 2643         กรุงเทพมหานคร                             State Quarantine
#
#      province_of_onset district_of_onset
# 2552            ภูเก็ต              ถลาง
# 2553            ภูเก็ต              ถลาง
# 2554              ยะลา             ธารโต
# 2555            นครพนม         ศรีสงคราม
# 2556     กรุงเทพมหานคร           ยานนาวา
# ...                ...               ...
# 2639          นราธิวาส           รือเสาะ
# 2640     กรุงเทพมหานคร           บางกะปิ
# 2641     กรุงเทพมหานคร           สวนหลวง
# 2642     กรุงเทพมหานคร           คลองสาน
# 2643     กรุงเทพมหานคร          ลาดพร้าว
#
# [84 rows x 11 columns]

# %% [markdown]
# # Smooth data by Binning

# %%
dataALL.iloc[2000:2500,4]
# Out:
# 2046    59.0
# 2047    39.0
# 2048    48.0
# 2049    21.0
# 2050    39.0
#         ...
# 2574    37.0
# 2575    33.0
# 2576    63.0
# 2577    41.0
# 2578    34.0
# Name: age, Length: 500, dtype: float64

# %%
my_data = dataALL.iloc[2000:2500,4]

# %%
plt.scatter(range(len(my_data)),my_data)

# %% [markdown]
# ### Sort

# %%
my_data_sorted = my_data.sort_values()

# %%
my_data_sorted
# Out:
# 2259     1.0
# 2455     1.0
# 2180     2.0
# 2448     2.0
# 2476     3.0
#         ...
# 2494    75.0
# 2512    75.0
# 2337    77.0
# 2219    78.0
# 2183    81.0
# Name: age, Length: 500, dtype: float64

# %%
plt.scatter(range(len(my_data)),my_data_sorted)

# %% [markdown]
# ### Bin - Rep

# %%
import numpy as np

# %% [markdown]
# * 0  :50     i=0   50*i : (50*i)+50
# * 50 :100    i=1   50*i : (50*i)+50
# * 100:150    i=2   50*i : (50*i)+50

# %%
bin = 10
bin_r = list()
step = int(len(my_data_sorted)/bin)
for i in range(bin):
    this_data = my_data_sorted[(step*i):(step*i)+step]    #ตัดข้อมูล
    rep = np.mean(this_data)   #เลือกตัวแทน
    bin_r.append(rep)

# %%
list(range(0,len(my_data_sorted),50))
# Out:
# [0, 50, 100, 150, 200, 250, 300, 350, 400, 450]

# %%
bin = 10
bin_r = list()
step = int(len(my_data_sorted)/bin)
for start in range(0,len(my_data_sorted),50):
    this_data = my_data_sorted[start:start+step]    #ตัดข้อมูล
    rep = np.mean(this_data)  #เลือกตัวแทน
    bin_r.append(rep)

# %%
bin_r
# Out:
# [14.8,
#  23.94,
#  28.14,
#  31.8,
#  35.41801519162394,
#  38.58,
#  42.72,
#  48.52,
#  56.42,
#  66.82]

# %% [markdown]
# ### Smooth

# %%
my_data_smoothed = list()
step = 0
this_bin = 0
for i in my_data_sorted:
    if step < 50:
        my_data_smoothed.append({'old_v':i,'new_v':bin_r[this_bin]})
        step = step + 1
    else:
        step = 0
        this_bin = this_bin + 1
        my_data_smoothed.append({'old_v':i,'new_v':bin_r[this_bin]})

# %%
my_data_smoothed
# Out:
# [{'old_v': 1.0, 'new_v': 14.8},
#  {'old_v': 1.0, 'new_v': 14.8},
#  {'old_v': 2.0, 'new_v': 14.8},
#  {'old_v': 2.0, 'new_v': 14.8},
#  {'old_v': 3.0, 'new_v': 14.8},
#  {'old_v': 4.0, 'new_v': 14.8},
#  {'old_v': 5.0, 'new_v': 14.8},
#  {'old_v': 5.0, 'new_v': 14.8},
#  {'old_v': 7.0, 'new_v': 14.8},
#  {'old_v': 7.0, 'new_v': 14.8},
#  {'old_v': 8.0, 'new_v': 14.8},
#  {'old_v': 9.0, 'new_v': 14.8},
#  {'old_v': 9.0, 'new_v': 14.8},
#  {'old_v': 10.0, 'new_v': 14.8},
#  {'old_v': 11.0, 'new_v': 14.8},
#  {'old_v': 11.0, 'new_v': 14.8},
#  {'old_v': 13.0, 'new_v': 14.8},
#  {'old_v': 13.0, 'new_v': 14.8},
#  {'old_v': 15.0, 'new_v': 14.8},
#  {'old_v': 15.0, 'new_v': 14.8},
#  {'old_v': 15.0, 'new_v': 14.8},
#  {'old_v': 16.0, 'new_v': 14.8},
#  {'old_v': 17.0, 'new_v': 14.8},
#  {'old_v': 17.0, 'new_v': 14.8},
#  {'old_v': 18.0, 'new_v': 14.8},
#  {'old_v': 18.0, 'new_v': 14.8},
#  {'old_v': 18.0, 'new_v': 14.8},
#  {'old_v': 19.0, 'new_v': 14.8},
#  {'old_v': 19.0, 'new_v': 14.8},
#  {'old_v': 19.0, 'new_v': 14.8},
#  {'old_v': 19.0, 'new_v': 14.8},
#  {'old_v': 20.0, 'new_v': 14.8},
#  {'old_v': 20.0, 'new_v': 14.8},
#  {'old_v': 20.0, 'new_v': 14.8},
#  {'old_v': 20.0, 'new_v': 14.8},
#  {'old_v': 20.0, 'new_v': 14.8},
#  {'old_v': 20.0, 'new_v': 14.8},
#  {'old_v': 21.0, 'new_v': 14.8},
#  {'old_v': 21.0, 'new_v': 14.8},
#  {'old_v': 21.0, 'new_v': 14.8},
#  {'old_v': 21.0, 'new_v': 14.8},
#  {'old_v': 21.0, 'new_v': 14.8},
#  {'old_v': 21.0, 'new_v': 14.8},
#  {'old_v': 21.0, 'new_v': 14.8},
#  {'old_v': 21.0, 'new_v': 14.8},
#  {'old_v': 21.0, 'new_v': 14.8},
#  {'old_v': 21.0, 'new_v': 14.8},
#  {'old_v': 21.0, 'new_v': 14.8},
#  {'old_v': 21.0, 'new_v': 14.8},
#  {'old_v': 22.0, 'new_v': 14.8},
#  {'old_v': 22.0, 'new_v': 23.94},
#  {'old_v': 22.0, 'new_v': 23.94},
#  {'old_v': 22.0, 'new_v': 23.94},
#  {'old_v': 22.0, 'new_v': 23.94},
#  {'old_v': 22.0, 'new_v': 23.94},
#  {'old_v': 22.0, 'new_v': 23.94},
#  {'old_v': 22.0, 'new_v': 23.94},
#  {'old_v': 22.0, 'new_v': 23.94},
#  {'old_v': 23.0, 'new_v': 23.94},
#  {'old_v': 23.0, 'new_v': 23.94},
#  {'old_v': 23.0, 'new_v': 23.94},
#  {'old_v': 23.0, 'new_v': 23.94},
#  {'old_v': 23.0, 'new_v': 23.94},
#  {'old_v': 23.0, 'new_v': 23.94},
#  {'old_v': 23.0, 'new_v': 23.94},
#  {'old_v': 23.0, 'new_v': 23.94},
#  {'old_v': 23.0, 'new_v': 23.94},
#  {'old_v': 23.0, 'new_v': 23.94},
#  {'old_v': 23.0, 'new_v': 23.94},
#  {'old_v': 24.0, 'new_v': 23.94},
#  {'old_v': 24.0, 'new_v': 23.94},
#  {'old_v': 24.0, 'new_v': 23.94},
#  {'old_v': 24.0, 'new_v': 23.94},
#  {'old_v': 24.0, 'new_v': 23.94},
#  {'old_v': 24.0, 'new_v': 23.94},
#  {'old_v': 24.0, 'new_v': 23.94},
#  {'old_v': 24.0, 'new_v': 23.94},
#  {'old_v': 24.0, 'new_v': 23.94},
#  {'old_v': 24.0, 'new_v': 23.94},
#  {'old_v': 24.0, 'new_v': 23.94},
#  {'old_v': 24.0, 'new_v': 23.94},
#  {'old_v': 25.0, 'new_v': 23.94},
#  {'old_v': 25.0, 'new_v': 23.94},
#  {'old_v': 25.0, 'new_v': 23.94},
#  {'old_v': 25.0, 'new_v': 23.94},
#  {'old_v': 25.0, 'new_v': 23.94},
#  {'old_v': 25.0, 'new_v': 23.94},
#  {'old_v': 25.0, 'new_v': 23.94},
#  {'old_v': 25.0, 'new_v': 23.94},
#  {'old_v': 25.0, 'new_v': 23.94},
#  {'old_v': 25.0, 'new_v': 23.94},
#  {'old_v': 25.0, 'new_v': 23.94},
#  {'old_v': 25.0, 'new_v': 23.94},
#  {'old_v': 25.0, 'new_v': 23.94},
#  {'old_v': 25.0, 'new_v': 23.94},
#  {'old_v': 26.0, 'new_v': 23.94},
#  {'old_v': 26.0, 'new_v': 23.94},
#  {'old_v': 26.0, 'new_v': 23.94},
#  {'old_v': 26.0, 'new_v': 23.94},
#  {'old_v': 26.0, 'new_v': 23.94},
#  {'old_v': 26.0, 'new_v': 23.94},
#  {'old_v': 26.0, 'new_v': 28.14},
#  {'old_v': 26.0, 'new_v': 28.14},
#  {'old_v': 27.0, 'new_v': 28.14},
#  {'old_v': 27.0, 'new_v': 28.14},
#  {'old_v': 27.0, 'new_v': 28.14},
#  {'old_v': 27.0, 'new_v': 28.14},
#  {'old_v': 27.0, 'new_v': 28.14},
#  {'old_v': 27.0, 'new_v': 28.14},
#  {'old_v': 27.0, 'new_v': 28.14},
#  {'old_v': 27.0, 'new_v': 28.14},
#  {'old_v': 27.0, 'new_v': 28.14},
#  {'old_v': 27.0, 'new_v': 28.14},
#  {'old_v': 27.0, 'new_v': 28.14},
#  {'old_v': 27.0, 'new_v': 28.14},
#  {'old_v': 27.0, 'new_v': 28.14},
#  {'old_v': 28.0, 'new_v': 28.14},
#  {'old_v': 28.0, 'new_v': 28.14},
#  {'old_v': 28.0, 'new_v': 28.14},
#  {'old_v': 28.0, 'new_v': 28.14},
#  {'old_v': 28.0, 'new_v': 28.14},
#  {'old_v': 28.0, 'new_v': 28.14},
#  {'old_v': 28.0, 'new_v': 28.14},
#  {'old_v': 28.0, 'new_v': 28.14},
#  {'old_v': 28.0, 'new_v': 28.14},
#  {'old_v': 28.0, 'new_v': 28.14},
#  {'old_v': 28.0, 'new_v': 28.14},
#  {'old_v': 28.0, 'new_v': 28.14},
#  {'old_v': 28.0, 'new_v': 28.14},
#  {'old_v': 28.0, 'new_v': 28.14},
#  {'old_v': 28.0, 'new_v': 28.14},
#  {'old_v': 29.0, 'new_v': 28.14},
#  {'old_v': 29.0, 'new_v': 28.14},
#  {'old_v': 29.0, 'new_v': 28.14},
#  {'old_v': 29.0, 'new_v': 28.14},
#  {'old_v': 29.0, 'new_v': 28.14},
#  {'old_v': 29.0, 'new_v': 28.14},
#  {'old_v': 29.0, 'new_v': 28.14},
#  {'old_v': 29.0, 'new_v': 28.14},
#  {'old_v': 29.0, 'new_v': 28.14},
#  {'old_v': 29.0, 'new_v': 28.14},
#  {'old_v': 29.0, 'new_v': 28.14},
#  {'old_v': 29.0, 'new_v': 28.14},
#  {'old_v': 30.0, 'new_v': 28.14},
#  {'old_v': 30.0, 'new_v': 28.14},
#  {'old_v': 30.0, 'new_v': 28.14},
#  {'old_v': 30.0, 'new_v': 28.14},
#  {'old_v': 30.0, 'new_v': 28.14},
#  {'old_v': 30.0, 'new_v': 28.14},
#  {'old_v': 30.0, 'new_v': 28.14},
#  {'old_v': 30.0, 'new_v': 28.14},
#  {'old_v': 30.0, 'new_v': 28.14},
#  {'old_v': 30.0, 'new_v': 31.8},
#  {'old_v': 30.0, 'new_v': 31.8},
#  {'old_v': 30.0, 'new_v': 31.8},
#  {'old_v': 30.0, 'new_v': 31.8},
#  {'old_v': 30.0, 'new_v': 31.8},
#  {'old_v': 30.0, 'new_v': 31.8},
#  {'old_v': 30.0, 'new_v': 31.8},
#  {'old_v': 30.0, 'new_v': 31.8},
#  {'old_v': 31.0, 'new_v': 31.8},
#  {'old_v': 31.0, 'new_v': 31.8},
#  {'old_v': 31.0, 'new_v': 31.8},
#  {'old_v': 31.0, 'new_v': 31.8},
#  {'old_v': 31.0, 'new_v': 31.8},
#  {'old_v': 31.0, 'new_v': 31.8},
#  {'old_v': 31.0, 'new_v': 31.8},
#  {'old_v': 31.0, 'new_v': 31.8},
#  {'old_v': 31.0, 'new_v': 31.8},
#  {'old_v': 31.0, 'new_v': 31.8},
#  {'old_v': 31.0, 'new_v': 31.8},
#  {'old_v': 32.0, 'new_v': 31.8},
#  {'old_v': 32.0, 'new_v': 31.8},
#  {'old_v': 32.0, 'new_v': 31.8},
#  {'old_v': 32.0, 'new_v': 31.8},
#  {'old_v': 32.0, 'new_v': 31.8},
#  {'old_v': 32.0, 'new_v': 31.8},
#  {'old_v': 32.0, 'new_v': 31.8},
#  {'old_v': 32.0, 'new_v': 31.8},
#  {'old_v': 32.0, 'new_v': 31.8},
#  {'old_v': 32.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 33.0, 'new_v': 31.8},
#  {'old_v': 34.0, 'new_v': 31.8},
#  {'old_v': 34.0, 'new_v': 31.8},
#  {'old_v': 34.0, 'new_v': 31.8},
#  {'old_v': 34.0, 'new_v': 31.8},
#  {'old_v': 34.0, 'new_v': 31.8},
#  {'old_v': 34.0, 'new_v': 35.41801519162394},
#  {'old_v': 34.0, 'new_v': 35.41801519162394},
#  {'old_v': 34.0, 'new_v': 35.41801519162394},
#  {'old_v': 34.0, 'new_v': 35.41801519162394},
#  {'old_v': 34.0, 'new_v': 35.41801519162394},
#  {'old_v': 34.0, 'new_v': 35.41801519162394},
#  {'old_v': 34.0, 'new_v': 35.41801519162394},
#  {'old_v': 35.0, 'new_v': 35.41801519162394},
#  {'old_v': 35.0, 'new_v': 35.41801519162394},
#  {'old_v': 35.0, 'new_v': 35.41801519162394},
#  {'old_v': 35.0, 'new_v': 35.41801519162394},
#  {'old_v': 35.0, 'new_v': 35.41801519162394},
#  {'old_v': 35.0, 'new_v': 35.41801519162394},
#  {'old_v': 35.0, 'new_v': 35.41801519162394},
#  {'old_v': 35.0, 'new_v': 35.41801519162394},
#  {'old_v': 35.0, 'new_v': 35.41801519162394},
#  {'old_v': 35.0, 'new_v': 35.41801519162394},
#  {'old_v': 35.0, 'new_v': 35.41801519162394},
#  {'old_v': 35.0, 'new_v': 35.41801519162394},
#  {'old_v': 35.0, 'new_v': 35.41801519162394},
#  {'old_v': 35.70010851159959, 'new_v': 35.41801519162394},
#  {'old_v': 35.70010851159959, 'new_v': 35.41801519162394},
#  {'old_v': 35.70010851159959, 'new_v': 35.41801519162394},
#  {'old_v': 35.70010851159959, 'new_v': 35.41801519162394},
#  {'old_v': 35.70010851159959, 'new_v': 35.41801519162394},
#  {'old_v': 35.70010851159959, 'new_v': 35.41801519162394},
#  {'old_v': 35.70010851159959, 'new_v': 35.41801519162394},
#  {'old_v': 36.0, 'new_v': 35.41801519162394},
#  {'old_v': 36.0, 'new_v': 35.41801519162394},
#  {'old_v': 36.0, 'new_v': 35.41801519162394},
#  {'old_v': 36.0, 'new_v': 35.41801519162394},
#  {'old_v': 36.0, 'new_v': 35.41801519162394},
#  {'old_v': 36.0, 'new_v': 35.41801519162394},
#  {'old_v': 36.0, 'new_v': 35.41801519162394},
#  {'old_v': 36.0, 'new_v': 35.41801519162394},
#  {'old_v': 36.0, 'new_v': 35.41801519162394},
#  {'old_v': 36.0, 'new_v': 35.41801519162394},
#  {'old_v': 36.0, 'new_v': 35.41801519162394},
#  {'old_v': 36.0, 'new_v': 35.41801519162394},
#  {'old_v': 36.0, 'new_v': 35.41801519162394},
#  {'old_v': 36.0, 'new_v': 35.41801519162394},
#  {'old_v': 37.0, 'new_v': 35.41801519162394},
#  {'old_v': 37.0, 'new_v': 35.41801519162394},
#  {'old_v': 37.0, 'new_v': 35.41801519162394},
#  {'old_v': 37.0, 'new_v': 35.41801519162394},
#  {'old_v': 37.0, 'new_v': 35.41801519162394},
#  {'old_v': 37.0, 'new_v': 35.41801519162394},
#  {'old_v': 37.0, 'new_v': 35.41801519162394},
#  {'old_v': 37.0, 'new_v': 35.41801519162394},
#  {'old_v': 37.0, 'new_v': 35.41801519162394},
#  {'old_v': 37.0, 'new_v': 35.41801519162394},
#  {'old_v': 37.0, 'new_v': 38.58},
#  {'old_v': 37.0, 'new_v': 38.58},
#  {'old_v': 37.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 38.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 39.0, 'new_v': 38.58},
#  {'old_v': 40.0, 'new_v': 38.58},
#  {'old_v': 40.0, 'new_v': 38.58},
#  {'old_v': 40.0, 'new_v': 38.58},
#  {'old_v': 40.0, 'new_v': 38.58},
#  {'old_v': 40.0, 'new_v': 38.58},
#  {'old_v': 40.0, 'new_v': 38.58},
#  {'old_v': 40.0, 'new_v': 38.58},
#  {'old_v': 40.0, 'new_v': 38.58},
#  {'old_v': 40.0, 'new_v': 38.58},
#  {'old_v': 40.0, 'new_v': 38.58},
#  {'old_v': 40.0, 'new_v': 38.58},
#  {'old_v': 40.0, 'new_v': 38.58},
#  {'old_v': 40.0, 'new_v': 38.58},
#  {'old_v': 40.0, 'new_v': 38.58},
#  {'old_v': 41.0, 'new_v': 42.72},
#  {'old_v': 41.0, 'new_v': 42.72},
#  {'old_v': 41.0, 'new_v': 42.72},
#  {'old_v': 41.0, 'new_v': 42.72},
#  {'old_v': 42.0, 'new_v': 42.72},
#  {'old_v': 42.0, 'new_v': 42.72},
#  {'old_v': 42.0, 'new_v': 42.72},
#  {'old_v': 42.0, 'new_v': 42.72},
#  {'old_v': 42.0, 'new_v': 42.72},
#  {'old_v': 42.0, 'new_v': 42.72},
#  {'old_v': 42.0, 'new_v': 42.72},
#  {'old_v': 42.0, 'new_v': 42.72},
#  {'old_v': 42.0, 'new_v': 42.72},
#  {'old_v': 42.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 43.0, 'new_v': 42.72},
#  {'old_v': 44.0, 'new_v': 42.72},
#  {'old_v': 44.0, 'new_v': 42.72},
#  {'old_v': 44.0, 'new_v': 42.72},
#  {'old_v': 44.0, 'new_v': 42.72},
#  {'old_v': 44.0, 'new_v': 42.72},
#  {'old_v': 44.0, 'new_v': 42.72},
#  {'old_v': 44.0, 'new_v': 42.72},
#  {'old_v': 45.0, 'new_v': 42.72},
#  {'old_v': 45.0, 'new_v': 42.72},
#  {'old_v': 45.0, 'new_v': 42.72},
#  {'old_v': 45.0, 'new_v': 42.72},
#  {'old_v': 45.0, 'new_v': 42.72},
#  {'old_v': 45.0, 'new_v': 42.72},
#  {'old_v': 45.0, 'new_v': 42.72},
#  {'old_v': 45.0, 'new_v': 42.72},
#  {'old_v': 45.0, 'new_v': 42.72},
#  {'old_v': 45.0, 'new_v': 42.72},
#  {'old_v': 46.0, 'new_v': 42.72},
#  {'old_v': 46.0, 'new_v': 42.72},
#  {'old_v': 46.0, 'new_v': 48.52},
#  {'old_v': 46.0, 'new_v': 48.52},
#  {'old_v': 46.0, 'new_v': 48.52},
#  {'old_v': 46.0, 'new_v': 48.52},
#  {'old_v': 47.0, 'new_v': 48.52},
#  {'old_v': 47.0, 'new_v': 48.52},
#  {'old_v': 47.0, 'new_v': 48.52},
#  {'old_v': 47.0, 'new_v': 48.52},
#  {'old_v': 47.0, 'new_v': 48.52},
#  {'old_v': 47.0, 'new_v': 48.52},
#  {'old_v': 47.0, 'new_v': 48.52},
#  {'old_v': 48.0, 'new_v': 48.52},
#  {'old_v': 48.0, 'new_v': 48.52},
#  {'old_v': 48.0, 'new_v': 48.52},
#  {'old_v': 48.0, 'new_v': 48.52},
#  {'old_v': 48.0, 'new_v': 48.52},
#  {'old_v': 48.0, 'new_v': 48.52},
#  {'old_v': 48.0, 'new_v': 48.52},
#  {'old_v': 48.0, 'new_v': 48.52},
#  {'old_v': 49.0, 'new_v': 48.52},
#  {'old_v': 49.0, 'new_v': 48.52},
#  {'old_v': 49.0, 'new_v': 48.52},
#  {'old_v': 49.0, 'new_v': 48.52},
#  {'old_v': 49.0, 'new_v': 48.52},
#  {'old_v': 49.0, 'new_v': 48.52},
#  {'old_v': 49.0, 'new_v': 48.52},
#  {'old_v': 50.0, 'new_v': 48.52},
#  {'old_v': 50.0, 'new_v': 48.52},
#  {'old_v': 50.0, 'new_v': 48.52},
#  {'old_v': 50.0, 'new_v': 48.52},
#  {'old_v': 50.0, 'new_v': 48.52},
#  {'old_v': 50.0, 'new_v': 48.52},
#  {'old_v': 50.0, 'new_v': 48.52},
#  {'old_v': 50.0, 'new_v': 48.52},
#  {'old_v': 51.0, 'new_v': 48.52},
#  {'old_v': 51.0, 'new_v': 48.52},
#  {'old_v': 51.0, 'new_v': 48.52},
#  {'old_v': 51.0, 'new_v': 48.52},
#  {'old_v': 51.0, 'new_v': 48.52},
#  {'old_v': 51.0, 'new_v': 48.52},
#  {'old_v': 52.0, 'new_v': 48.52},
#  {'old_v': 52.0, 'new_v': 48.52},
#  {'old_v': 52.0, 'new_v': 48.52},
#  {'old_v': 52.0, 'new_v': 48.52},
#  {'old_v': 53.0, 'new_v': 48.52},
#  {'old_v': 53.0, 'new_v': 48.52},
#  {'old_v': 53.0, 'new_v': 48.52},
#  {'old_v': 54.0, 'new_v': 48.52},
#  {'old_v': 54.0, 'new_v': 48.52},
#  {'old_v': 54.0, 'new_v': 48.52},
#  {'old_v': 54.0, 'new_v': 48.52},
#  {'old_v': 54.0, 'new_v': 56.42},
#  {'old_v': 54.0, 'new_v': 56.42},
#  {'old_v': 54.0, 'new_v': 56.42},
#  {'old_v': 54.0, 'new_v': 56.42},
#  {'old_v': 55.0, 'new_v': 56.42},
#  {'old_v': 55.0, 'new_v': 56.42},
#  {'old_v': 55.0, 'new_v': 56.42},
#  {'old_v': 55.0, 'new_v': 56.42},
#  {'old_v': 55.0, 'new_v': 56.42},
#  {'old_v': 55.0, 'new_v': 56.42},
#  {'old_v': 55.0, 'new_v': 56.42},
#  {'old_v': 55.0, 'new_v': 56.42},
#  {'old_v': 56.0, 'new_v': 56.42},
#  {'old_v': 56.0, 'new_v': 56.42},
#  {'old_v': 56.0, 'new_v': 56.42},
#  {'old_v': 56.0, 'new_v': 56.42},
#  {'old_v': 56.0, 'new_v': 56.42},
#  {'old_v': 56.0, 'new_v': 56.42},
#  {'old_v': 56.0, 'new_v': 56.42},
#  {'old_v': 56.0, 'new_v': 56.42},
#  {'old_v': 57.0, 'new_v': 56.42},
#  {'old_v': 57.0, 'new_v': 56.42},
#  {'old_v': 57.0, 'new_v': 56.42},
#  {'old_v': 57.0, 'new_v': 56.42},
#  {'old_v': 57.0, 'new_v': 56.42},
#  {'old_v': 58.0, 'new_v': 56.42},
#  {'old_v': 58.0, 'new_v': 56.42},
#  {'old_v': 58.0, 'new_v': 56.42},
#  {'old_v': 58.0, 'new_v': 56.42},
#  {'old_v': 58.0, 'new_v': 56.42},
#  {'old_v': 58.0, 'new_v': 56.42},
#  {'old_v': 58.0, 'new_v': 56.42},
#  {'old_v': 58.0, 'new_v': 56.42},
#  {'old_v': 59.0, 'new_v': 56.42},
#  {'old_v': 59.0, 'new_v': 56.42},
#  {'old_v': 59.0, 'new_v': 56.42},
#  {'old_v': 59.0, 'new_v': 56.42},
#  {'old_v': 59.0, 'new_v': 56.42},
#  {'old_v': 59.0, 'new_v': 56.42},
#  {'old_v': 59.0, 'new_v': 56.42},
#  {'old_v': 60.0, 'new_v': 56.42},
#  {'old_v': 60.0, 'new_v': 56.42},
#  {'old_v': 60.0, 'new_v': 56.42},
#  {'old_v': 60.0, 'new_v': 56.42},
#  {'old_v': 60.0, 'new_v': 56.42},
#  {'old_v': 60.0, 'new_v': 56.42},
#  {'old_v': 60.0, 'new_v': 56.42},
#  {'old_v': 60.0, 'new_v': 56.42},
#  {'old_v': 61.0, 'new_v': 56.42},
#  {'old_v': 61.0, 'new_v': 56.42},
#  {'old_v': 62.0, 'new_v': 56.42},
#  {'old_v': 62.0, 'new_v': 66.82},
#  {'old_v': 62.0, 'new_v': 66.82},
#  {'old_v': 62.0, 'new_v': 66.82},
#  {'old_v': 63.0, 'new_v': 66.82},
#  {'old_v': 63.0, 'new_v': 66.82},
#  {'old_v': 63.0, 'new_v': 66.82},
#  {'old_v': 63.0, 'new_v': 66.82},
#  {'old_v': 63.0, 'new_v': 66.82},
#  {'old_v': 64.0, 'new_v': 66.82},
#  {'old_v': 64.0, 'new_v': 66.82},
#  {'old_v': 64.0, 'new_v': 66.82},
#  {'old_v': 64.0, 'new_v': 66.82},
#  {'old_v': 64.0, 'new_v': 66.82},
#  {'old_v': 64.0, 'new_v': 66.82},
#  {'old_v': 64.0, 'new_v': 66.82},
#  {'old_v': 64.0, 'new_v': 66.82},
#  {'old_v': 65.0, 'new_v': 66.82},
#  {'old_v': 65.0, 'new_v': 66.82},
#  {'old_v': 65.0, 'new_v': 66.82},
#  {'old_v': 66.0, 'new_v': 66.82},
#  {'old_v': 67.0, 'new_v': 66.82},
#  {'old_v': 67.0, 'new_v': 66.82},
#  {'old_v': 67.0, 'new_v': 66.82},
#  {'old_v': 68.0, 'new_v': 66.82},
#  {'old_v': 68.0, 'new_v': 66.82},
#  {'old_v': 69.0, 'new_v': 66.82},
#  {'old_v': 70.0, 'new_v': 66.82},
#  {'old_v': 70.0, 'new_v': 66.82},
#  {'old_v': 70.0, 'new_v': 66.82},
#  {'old_v': 71.0, 'new_v': 66.82},
#  {'old_v': 71.0, 'new_v': 66.82},
#  {'old_v': 72.0, 'new_v': 66.82},
#  {'old_v': 72.0, 'new_v': 66.82},
#  {'old_v': 73.0, 'new_v': 66.82},
#  {'old_v': 74.0, 'new_v': 66.82},
#  {'old_v': 74.0, 'new_v': 66.82},
#  {'old_v': 74.0, 'new_v': 66.82},
#  {'old_v': 75.0, 'new_v': 66.82},
#  {'old_v': 75.0, 'new_v': 66.82},
#  {'old_v': 77.0, 'new_v': 66.82},
#  {'old_v': 78.0, 'new_v': 66.82},
#  {'old_v': 81.0, 'new_v': 66.82}]

# %%
my_df = pd.DataFrame(my_data_smoothed) #แปลง Dict เป็น ตาราง pandas (ยังไม่ได้สอน)
my_df
# Out:
#      old_v  new_v
# 0      1.0  14.80
# 1      1.0  14.80
# 2      2.0  14.80
# 3      2.0  14.80
# 4      3.0  14.80
# ..     ...    ...
# 495   75.0  66.82
# 496   75.0  66.82
# 497   77.0  66.82
# 498   78.0  66.82
# 499   81.0  66.82
#
# [500 rows x 2 columns]

# %%
plt.scatter(range(len(my_data)),my_df['new_v'])

# %% [markdown]
# ## แทนค่ากลับลงไปในตาราง

# %% [markdown]
# # การต่อตาราง (แนวแกน X)

# %% [markdown]
# หาจำนวนร้านค้าที่แสดงเป็นอันดับ 1-4 ที่ถูกกดเข้าไปดูหลังจาก search โดยร้านค้านั้นตั้งอยู่ที่เชียงใหม่

# %%
w_res = pd.read_csv(os.path.join(path,'w_restaurant.csv'))
w_res.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-1e10d543b845> in <cell line: 1>()
# ----> 1 w_res = pd.read_csv(os.path.join(path,'w_restaurant.csv'))
#       2 w_res.head()
#
# NameError: name 'path' is not defined

# %%
search_click = pd.read_csv(os.path.join(path,'search_click.csv'))
search_click.head()
# Out:
#   click_timestamp                             search_id  ...  time_diff_nanos   ads
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1  ...     2.222400e+15  True
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e  ...     4.608380e+14  True
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224  ...     2.581490e+15  True
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b  ...     1.404580e+15  True
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639  ...     9.333590e+14  True
#
# [5 rows x 6 columns]

# %%
import numpy as np

# %%
np.random.choice(['นิชา','oil','กี้'])
# Out:
# 'oil'

# %% [markdown]
# หาร้านที่ตั้งอยู่ที่ จ.เชียงใหม่

# %%
w_res[w_res['city_name']=='Chiang Mai']
# Out:
#             id                          name  ...  pet_friendly  delivery
# 36          70                   Wrap Master  ...           0.0       1.0
# 40          75                         Sozen  ...           NaN       NaN
# 52          98           ไวท์ดราก้อน หมูกะทะ  ...           NaN       NaN
# 60         111  เต-ชา ก๋วยเตี๋ยวไข่ไดโนเสาร์  ...           0.0       0.0
# 79         147            ก๋วยเตี๋ยวเรือสะใจ  ...           NaN       NaN
# ...        ...                           ...  ...           ...       ...
# 246783  339922                 ส้มตำลำฮิมกอง  ...           NaN       NaN
# 246803  339957       ไก่ทอดปักษ์ใต้ นายหัวโต  ...           NaN       NaN
# 246808  339976             แคลิฟอร์เนียเวร็ป  ...           NaN       NaN
# 246813  339998        TOONGs COFFEE Roasters  ...           NaN       NaN
# 246826  340031                     ลาบเขยยอง  ...           NaN       NaN
#
# [15670 rows x 32 columns]

# %% [markdown]
# หา records ที่ถูก click เวลา 4-6 โมงเย็น

# %% [markdown]
# ตรวจสอบชนิดข้อมูล

# %%
search_click.iloc[0,0]
# Out:
# '11:38.9'

# %% [markdown]
# แปลงให้เป็น datetime

# %%
from datetime import datetime

# %%
pd.to_datetime(search_click.iloc[0,0])
# Out:
# Timestamp('2021-09-13 11:38:54')

# %%
#ไม่มีข้อมูล timestamp

# %% [markdown]
# records ที่ถูกแสดงเป็นอันดับที่ 1-4

# %%
search_click[(search_click['display_position']>=0)&(search_click['display_position']<=3)]
# Out:
#         click_timestamp  ...    ads
# 0               11:38.9  ...   True
# 1               30:51.3  ...   True
# 2               32:09.6  ...   True
# 3               00:59.8  ...   True
# 4               23:36.8  ...   True
# ...                 ...  ...    ...
# 1047860         00:56.4  ...  False
# 1047861         57:44.9  ...  False
# 1047862         59:39.1  ...  False
# 1047863         54:14.9  ...  False
# 1047864         43:17.6  ...  False
#
# [484569 rows x 6 columns]

# %% [markdown]
# จำนวนร้าน ที่ถูกแสดงเป็นอันดับที่ 1-4

# %%
search_click_14 = search_click[(search_click['display_position']>=0)&(search_click['display_position']<=3)].drop_duplicates(subset=['business_id'])
search_click_14
# Out:
#         click_timestamp  ...    ads
# 0               11:38.9  ...   True
# 1               30:51.3  ...   True
# 2               32:09.6  ...   True
# 3               00:59.8  ...   True
# 4               23:36.8  ...   True
# ...                 ...  ...    ...
# 1047799         44:03.1  ...  False
# 1047829         58:02.2  ...  False
# 1047841         24:35.6  ...  False
# 1047848         49:27.0  ...  False
# 1047855         27:39.0  ...  False
#
# [78810 rows x 6 columns]

# %% [markdown]
# # การต่อตารางแนวแกน X มี 2 คำสั่ง
# * merge two table(.merge())
#
# * copy a column from other table (.map()) คล้าย ๆ merge แต่ดึงมาแค่บางคอลัมน์

# %% [markdown]
# Merge()

# %% [markdown]
# Map()

# %% [markdown]
# ## ต่อ Smooth by Binning

# %%
dataALL_cut = dataALL.iloc[2000:2500,:5]
dataALL_cut
# Out:
#        No. announce_date Notified date   sex   age
# 2000  2001    2020-04-04      3/4/2020   ชาย  34.0
# 2001  2002    2020-04-04      3/4/2020  หญิง  31.0
# 2002  2003    2020-04-04      3/4/2020  หญิง  58.0
# 2003  2004    2020-04-04      3/4/2020  หญิง  56.0
# 2004  2005    2020-04-04      3/4/2020  หญิง  37.0
# ...    ...           ...           ...   ...   ...
# 2495  2496    2020-04-11     10/4/2020   ชาย  21.0
# 2496  2497    2020-04-11     10/4/2020  หญิง   4.0
# 2497  2498    2020-04-11     10/4/2020   ชาย  45.0
# 2498  2499    2020-04-11     10/4/2020  หญิง  30.0
# 2499  2500    2020-04-11     10/4/2020   ชาย  40.0
#
# [500 rows x 5 columns]

# %%
my_df
# Out:
#      old_v  new_v
# 0      1.0  14.74
# 1      1.0  14.74
# 2      2.0  14.74
# 3      2.0  14.74
# 4      3.0  14.74
# ..     ...    ...
# 495   75.0  67.00
# 496   77.0  67.00
# 497   78.0  67.00
# 498   81.0  67.00
# 499   91.0  67.00
#
# [500 rows x 2 columns]

# %%
my_df_unique = my_df.drop_duplicates(subset=['old_v'])
my_df_unique
# Out:
#      old_v  new_v
# 0      1.0  14.74
# 2      2.0  14.74
# 4      3.0  14.74
# 6      4.0  14.74
# 7      5.0  14.74
# ..     ...    ...
# 495   75.0  67.00
# 496   77.0  67.00
# 497   78.0  67.00
# 498   81.0  67.00
# 499   91.0  67.00
#
# [77 rows x 2 columns]

# %%
dataALL_cut['smooth_age'] = dataALL_cut['age'].map(my_df_unique.set_index('old_v')['new_v'])
dataALL_cut
# Out:
#        No. announce_date Notified date   sex   age  smooth_age
# 2000  2001    2020-04-04      3/4/2020   ชาย  34.0   32.280000
# 2001  2002    2020-04-04      3/4/2020  หญิง  31.0   32.280000
# 2002  2003    2020-04-04      3/4/2020  หญิง  58.0   56.560000
# 2003  2004    2020-04-04      3/4/2020  หญิง  56.0   56.560000
# 2004  2005    2020-04-04      3/4/2020  หญิง  37.0   35.836009
# ...    ...           ...           ...   ...   ...         ...
# 2495  2496    2020-04-11     10/4/2020   ชาย  21.0   14.740000
# 2496  2497    2020-04-11     10/4/2020  หญิง   4.0   14.740000
# 2497  2498    2020-04-11     10/4/2020   ชาย  45.0   43.840000
# 2498  2499    2020-04-11     10/4/2020  หญิง  30.0   28.240000
# 2499  2500    2020-04-11     10/4/2020   ชาย  40.0   39.140000
#
# [500 rows x 6 columns]

# %%
plt.scatter(range(len(my_data)),my_data)

# %%
plt.scatter(range(len(my_data)),dataALL_cut['smooth_age'])

# %% [markdown]
# ## [PD] Group by

# %% [markdown]
# ### แต่ละจังหวัดมีอายุเฉลี่ยของคนที่ตรวจพบโรคเป็นกี่ปี (เรียงจากน้อยไปหามาก)

# %%
dataALL
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1    2020-01-12    99/99/9999  หญิง  61.0   ปี       China
# 1            2    2020-01-17    99/99/9999  หญิง  74.0   ปี       China
# 2            3    2020-01-22    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4    2020-01-22    99/99/9999   ชาย  68.0   ปี       China
# 4            5    2020-01-24    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767    2021-08-12     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768    2021-08-12     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769    2021-08-12     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770    2021-08-12     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771    2021-08-12     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [827611 rows x 11 columns]

# %%
dataALL.groupby('province_of_onset').mean()
# Out:
# <ipython-input-147-aaf7daec95c2>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataALL.groupby('province_of_onset').mean()
#                              No.        age
# province_of_onset
#  กาญจนบุรี         763651.000000  29.000000
#  ชลบุรี            763654.000000  23.000000
#  ตราด              763585.000000  46.000000
#  นครปฐม            763589.000000  29.000000
#  สมุทรสงคราม       763602.843750  35.861459
# ...                          ...        ...
# เวียงสา            392058.600000  35.700109
# แพร่               499238.098698  34.868442
# แม่ฮ่องสอน         330666.227642  27.265855
# แล้วป่วย           627895.000000  43.000000
# ไม่ระบุ            585796.424242  35.696970
#
# [179 rows x 2 columns]

# %%
dataprovage = dataALL.groupby('province_of_onset').mean().reset_index()[['province_of_onset','age']]
dataprovage.sort_values(by=['age'])
# Out:
# <ipython-input-148-e623aa022691>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataprovage = dataALL.groupby('province_of_onset').mean().reset_index()[['province_of_onset','age']]
#     province_of_onset   age
# 60          ปทุมธานี.   5.0
# 68          ปลายพระยา  15.0
# 118          สมุทสาคร  15.0
# 50              นาวัง  19.0
# 138        สุวรรณภูมิ  20.0
# ..                ...   ...
# 87            ยานนาวา  57.0
# 112       สมุทรปรากรร  65.0
# 34             นคนปฐม  67.0
# 99            ลำลูกกา  67.0
# 146           อยุทธยา  70.0
#
# [179 rows x 2 columns]

# %% [markdown]
# ## [PD] Sample record

# %%
dataALL.shape
# Out:
# (827611, 11)

# %% [markdown]
# ####sampling

# %%
dataALL.sample(n=100)
# Out:
#            No. announce_date Notified date   sex        age Unit nationality  \
# 430237  430238    2021-07-21     20/7/2021  หญิง  32.000000   ปี    Thailand
# 170546  170547    2021-06-04      3/6/2021  หญิง  60.000000   ปี    Thailand
# 321418  321419    2021-07-10      9/7/2021   ชาย  22.000000   ปี    Thailand
# 457508  457509    2021-07-23     22/7/2021  หญิง  27.000000   ปี    Thailand
# 110080  110081    2021-05-17     16/5/2021   ชาย  39.000000   ปี    Thailand
# ...        ...           ...           ...   ...        ...  ...         ...
# 764397  764398    2021-08-09      8/8/2021   ชาย  45.000000   ปี     Burmese
# 764521  764522    2021-08-09      8/8/2021  หญิง  44.000000   ปี    Thailand
# 395077  395078    2021-07-18     17/7/2021   ชาย  40.000000   ปี     Burmese
# 706015  706016    2021-08-06      5/8/2021  หญิง  35.700109   ปี        Thai
# 674354  674355    2021-08-05      4/8/2021  หญิง  42.000000   ปี    Thailand
#
#        province_of_isolation                                           risk  \
# 430237              เพชรบุรี    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 170546                ชลบุรี  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 321418                ชลบุรี                           อยู่ระหว่างการสอบสวน
# 457508               ราชบุรี                                          อื่นๆ
# 110080         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# ...                      ...                                            ...
# 764397            ปราจีนบุรี                                   สถานที่ทำงาน
# 764521            ฉะเชิงเทรา                                   สถานที่ทำงาน
# 395077             สมุทรสาคร    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 706015            นครราชสีมา                           อยู่ระหว่างการสอบสวน
# 674354               นนทบุรี    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#        province_of_onset district_of_onset
# 430237          เพชรบุรี              ชะอำ
# 170546        ฉะเชิงเทรา           บางปะกง
# 321418            ชลบุรี          บางละมุง
# 457508           ราชบุรี           โพธาราม
# 110080               NaN               NaN
# ...                  ...               ...
# 764397        ปราจีนบุรี        ศรีมหาโพธิ
# 764521        ฉะเชิงเทรา     บางน้ำเปรี้ยว
# 395077            นครปฐม           สามพราน
# 706015               NaN               NaN
# 674354           นนทบุรี           บางใหญ่
#
# [100 rows x 11 columns]

# %% [markdown]
# #### bootstrap sampling (สุ่มแบบใส่คืน)

# %%
dataALL.sample(n=100,replace=True)
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 539454  539455    2021-07-28     27/7/2021  หญิง  28.0   ปี    Thailand
# 160736  160737    2021-06-01     31/5/2021   ชาย  59.0   ปี    Thailand
# 668247  668248    2021-08-04      3/8/2021  หญิง   7.0   ปี        ไทย?
# 517020  517021    2021-07-27     26/7/2021   ชาย  23.0   ปี     Burmese
# 503886  503887    2021-07-26     25/7/2021   ชาย  17.0   ปี    Thailand
# ...        ...           ...           ...   ...   ...  ...         ...
# 110648  110649    2021-05-17     16/5/2021   ชาย  38.0   ปี    Thailand
# 777981  777982    2021-08-10      9/8/2021  หญิง   3.0   ปี     Burmese
# 587048  587049    2021-07-31     30/7/2021   ชาย  48.0   ปี    Thailand
# 516280  516281    2021-07-27     26/7/2021   ชาย  40.0   ปี    Thailand
# 62695    62696    2021-04-29     28/4/2021   ชาย  76.0   ปี    Thailand
#
#        province_of_isolation  \
# 539454         กรุงเทพมหานคร
# 160736                ชลบุรี
# 668247         กรุงเทพมหานคร
# 517020       ประจวบคีรีขันธ์
# 503886            ปราจีนบุรี
# ...                      ...
# 110648         กรุงเทพมหานคร
# 777981               นนทบุรี
# 587048                 ระยอง
# 516280             สมุทรสาคร
# 62695              เชียงใหม่
#
#                                                     risk province_of_onset  \
# 539454       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้     กรุงเทพมหานคร
# 160736       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้            ชลบุรี
# 668247                                             อื่นๆ     กรุงเทพมหานคร
# 517020  การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน   ประจวบคีรีขันธ์
# 503886                              อยู่ระหว่างการสอบสวน        ปราจีนบุรี
# ...                                                  ...               ...
# 110648                                  ทัณฑสถาน/เรือนจำ               NaN
# 777981  การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน           นนทบุรี
# 587048  การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน             ระยอง
# 516280       สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้            นครปฐม
# 62695      ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว         เชียงใหม่
#
#        district_of_onset
# 539454       บางขุนเทียน
# 160736           ศรีราชา
# 668247       บางขุนเทียน
# 517020            หัวหิน
# 503886   เมืองปราจีนบุรี
# ...                  ...
# 110648               NaN
# 777981      เมืองนนทบุรี
# 587048              แกลง
# 516280           สามพราน
# 62695             อมก๋อย
#
# [100 rows x 11 columns]

# %% [markdown]
# ## [PD] Save file

# %%
dataprovage.sort_values(by=['age']).to_csv('avg_age_prov.csv')

# %% [markdown]
# ## [PD] การสร้างตาราง pandas
#
# ![Unknown.jpg](data:image/jpeg;base64,...)

# %%
sales = [{'account':'Jones LLC', 'Jan':150, 'Feb':200, 'Mar':140},
         {'account':'Alpha Co', 'Jan':200, 'Feb':210, 'Mar':215},
         {'account':'Blue Inc', 'Jan':50, 'Feb':90, 'Mar':95}]
df = pd.DataFrame(sales)
df
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %%
sales = [['Jones LLC',150,200,140],
         ['Alpha Co',200,210,215],
         ['Blue Inc',50,90,95]]
labels = ['account','Jan','Feb','Mar']
df = pd.DataFrame.from_records(sales,columns=labels)
df
# Out:
#      account  Jan  Feb  Mar
# 0  Jones LLC  150  200  140
# 1   Alpha Co  200  210  215
# 2   Blue Inc   50   90   95

# %% [markdown]
# ## Pre-test

# %%
dataALL
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1    2020-01-12    99/99/9999  หญิง  61.0   ปี       China
# 1            2    2020-01-17    99/99/9999  หญิง  74.0   ปี       China
# 2            3    2020-01-22    99/99/9999  หญิง  73.0   ปี    Thailand
# 3            4    2020-01-22    99/99/9999   ชาย  68.0   ปี       China
# 4            5    2020-01-24    99/99/9999  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767    2021-08-12     11/8/2021   ชาย  52.0   ปี        ไทย?
# 839767  839768    2021-08-12     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769    2021-08-12     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770    2021-08-12     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771    2021-08-12     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [827611 rows x 11 columns]

# %% [markdown]
# ตัวอย่างผู้ติดโโควิดแต่ละสัญชาติมีกี่คน

# %%
dataALL.groupby(["nationality"])[['nationality']].count()
# Out:
#                   nationality
# nationality
# Afghan / Afghani            4
# Afghanistan                 3
# African                     3
# Albania                     4
# Algeria                     1
# ...                       ...
# ไทย?                    83416
# ไทยใหญ่                     1
# ไทใหญ่                      1
# ไนจีเรีย                    1
# ไม่มีสัญชาติ                3
#
# [242 rows x 1 columns]

# %%
dataALL.groupby(["nationality"])[['No.']].count().sort_values(by=['No.'],ascending=False)
# Out:
#                 No.
# nationality
# Thailand     640157
# ไทย?          83416
# Burmese       59124
# Burma         18759
# Cambodian     15066
# ...             ...
# Gambia            1
# Gambia, The       1
# Somalia           1
# Slovenia          1
# Malawi            1
#
# [242 rows x 1 columns]

# %%
dataALL.groupby(["risk"])[['risk']].count()
# Out:
#                                                     risk
# risk
#  Samui plus                                            2
# 10.อื่นๆ                                              22
# 2.สัมผัสผู้ติดเชื้อ                                   10
# ACF รองเมือง                                          24
# ACF สนามกีฬาธูปะเตมีย์                                23
# ...                                                  ...
# ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว      18896
# ไปสถานที่เสี่ยง เช่น ตลาด สถานที่ชุมชน                 1
# ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต                986
# ไปเที่ยวสถานบันเทิงในอุบลที่พบการระบาดของโรค Ubar      1
# ไปแหล่งชุมชน/สถานที่คนหนาแน่น                          5
#
# [128 rows x 1 columns]

# %%
dataALL.groupby(["risk"])[['No.']].count().sort_values(by=['No.'],ascending=False)
# Out:
#                                                      No.
# risk
# สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้       296943
# อื่นๆ                                             143616
# การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน  132530
# อยู่ระหว่างการสอบสวน                              102521
# ทัณฑสถาน/เรือนจำ                                   52054
# ...                                                  ...
# สัมผัสสามีสะอาด เขตบ้าน (รพ.มหาชัย 2)                  1
# Samui plus                                             1
# SHUI                                                   1
# Cluster โรงงานทำขนม บางขุนเทียน                        1
# สัมผัสผู้ป่วยยืนยันเพื่อนร่วมงาน                       1
#
# [128 rows x 1 columns]

# %% [markdown]
# อายุเฉลี่ยของ nationality แต่ละแบบ

# %%
dataALL.groupby(["nationality"])[['age']].mean().sort_values(by=['age'],ascending=False)
# Out:
#                       age
# nationality
# Myanmar              77.9
# Argentine            77.0
# Croatia              73.0
# Gambia               71.0
# French Guiana        66.5
# ...                   ...
# Kosovo               20.0
# Libya                18.0
# iranian              18.0
# Azerbaijan           12.0
# Congo (Brazzaville)   4.0
#
# [242 rows x 1 columns]
